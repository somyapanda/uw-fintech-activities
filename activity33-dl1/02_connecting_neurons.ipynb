# %% [markdown]
# # Instructor Do: Connecting Neurons

# %%
# Initial imports
import pandas as pd
import numpy as np
from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler


# %matplotlib inline

# %% [markdown]
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Dense

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
# ## Creating Dummy Data

# %%
# Creating dummy non-linear data
X_moons, y_moons = make_moons(n_samples=1000, noise=0.08, random_state=78)

# %%
# Transforming y_moons to a vertical vector
y_moons = y_moons.reshape(-1, 1)

# %%
# Creating a DataFrame to plot the non-linear dummy data
df_moons = pd.DataFrame(X_moons, columns=["Feature 1", "Feature 2"])
df_moons["Target"] = y_moons
df_moons.head()
# Out:
#    Feature 1  Feature 2  Target
# 0   0.676217   0.815220       0
# 1   1.487143  -0.210519       1
# 2  -1.027709   0.354966       0
# 3   0.236012   1.025531       0
# 4   1.856695  -0.042783       1

# %%
# Plotting the non-linear dummy data
df_moons.plot.scatter(x="Feature 1", y="Feature 2", c="Target", colormap="winter")

# %% [markdown]
# ## Data Preprocessing

# %%
# Create training and testing sets
X_moon_train, X_moon_test, y_moon_train, y_moon_test = train_test_split(
    X_moons, y_moons, random_state=78
)

# %%
# Create the scaler instance
X_moon_scaler = StandardScaler()

# %%
# Fit the scaler
X_moon_scaler.fit(X_moon_train)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
# Scale the data
X_moon_train_scaled = X_moon_scaler.transform(X_moon_train)
X_moon_test_scaled = X_moon_scaler.transform(X_moon_test)

# %% [markdown]
# ## Neural Network Model Creation
#
# ![Simple neural network](../Images/simple-nn.png)

# %%
# Create the sequential model
nn = Sequential()

# %% [markdown]
# ### Fisrt Layer
#
# ![First Layer](../Images/simple-nn-layer-1.png)

# %%
# First layer
number_inputs = 2
number_hidden_nodes = 6

nn.add(Dense(units=number_hidden_nodes, activation="relu", input_dim=number_inputs))

# %% [markdown]
# ### Output Layer
#
# ![Output layer](../Images/simple-nn-layer-2.png)

# %%
# Output layer
number_classes = 1

nn.add(Dense(units=number_classes, activation="sigmoid"))

# %%
# Model summary
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 6)                 18
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 7
# =================================================================
# Total params: 25
# Trainable params: 25
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Compile the Model

# %%
# Compile model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %% [markdown]
# ## Fit the Model

# %%
# Training the model with the non-linear data
model_moon = nn.fit(X_moon_train_scaled, y_moon_train, epochs=100)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 1s 2ms/step - loss: 0.7442 - accuracy: 0.3960
# Epoch 2/100
# 24/24 [==============================] - 0s 997us/step - loss: 0.7068 - accuracy: 0.5237
# Epoch 3/100
# 24/24 [==============================] - 0s 915us/step - loss: 0.6745 - accuracy: 0.5310
# Epoch 4/100
# 24/24 [==============================] - 0s 878us/step - loss: 0.6401 - accuracy: 0.5458
# Epoch 5/100
# 24/24 [==============================] - 0s 891us/step - loss: 0.6101 - accuracy: 0.5931
# Epoch 6/100
# 24/24 [==============================] - 0s 845us/step - loss: 0.5970 - accuracy: 0.6724
# Epoch 7/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5591 - accuracy: 0.7753
# Epoch 8/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5332 - accuracy: 0.7758
# Epoch 9/100
# 24/24 [==============================] - 0s 921us/step - loss: 0.5121 - accuracy: 0.7958
# Epoch 10/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4851 - accuracy: 0.8062
# Epoch 11/100
# 24/24 [==============================] - 0s 986us/step - loss: 0.4583 - accuracy: 0.8348
# Epoch 12/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.
100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2364 - accuracy: 0.8973
# Epoch 58/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2262 - accuracy: 0.9091
# Epoch 59/100
# 24/24 [==============================] - 0s 998us/step - loss: 0.2401 - accuracy: 0.8984
# Epoch 60/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2275 - accuracy: 0.9002
# Epoch 61/100
# 24/24 [==============================] - 0s 985us/step - loss: 0.2512 - accuracy: 0.8943
# Epoch 62/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2390 - accuracy: 0.9005
# Epoch 63/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2389 - accuracy: 0.9005
# Epoch 64/100
# 24/24 [==============================] - 0s 862us/step - loss: 0.2474 - accuracy: 0.8882
# Epoch 65/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2315 - accuracy: 0.9038
# Epoch 66/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2349 - accuracy: 0.8957
# Epoch 67/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2415 - accuracy: 0.9006
# Epoch 68/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2324 - accuracy: 0.9004
# Epoch 69/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2513 - accuracy: 0.8879
# Epoch 70/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2403 - accuracy: 0.8942
# Epoch 71/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2309 - accuracy: 0.9028
# Epoch 72/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2447 - accuracy: 0.8942
# Epoch 73/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2036 - accuracy: 0.9165
# Epoch 74/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2196 - accuracy: 0.9119
# Epoch 75/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2282 - accuracy: 0.9050
# Epoch 76/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2462 - accuracy: 0.8894
# Epoch 77/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2277 - accuracy: 0.9059
# Epoch 78/100
# 24/24 [==============================] - 0s 999us/step - loss: 0.2222 - accuracy: 0.9042
# Epoch 79/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2263 - accuracy: 0.8985
# Epoch 80/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2463 - accuracy: 0.8990
# Epoch 81/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2368 - accuracy: 0.8900
# Epoch 82/100
# 24/24 [==============================] - 0s 952us/step - loss: 0.2023 - accuracy: 0.9220
# Epoch 83/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2205 - accuracy: 0.9052
# Epoch 84/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2328 - accuracy: 0.8989
# Epoch 85/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2364 - accuracy: 0.9031
# Epoch 86/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2127 - accuracy: 0.9064
# Epoch 87/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2174 - accuracy: 0.9058
# Epoch 88/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2491 - accuracy: 0.8945
# Epoch 89/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2207 - accuracy: 0.8991
# Epoch 90/100
# 24/24 [==============================] - 0s 972us/step - loss: 0.1908 - accuracy: 0.9234
# Epoch 91/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2416 - accuracy: 0.8934
# Epoch 92/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2277 - accuracy: 0.8980
# Epoch 93/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2212 - accuracy: 0.9088
# Epoch 94/100
# 24/24 [==============================] - 0s 961us/step - loss: 0.2306 - accuracy: 0.9032
# Epoch 95/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2231 - accuracy: 0.9068
# Epoch 96/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1924 - accuracy: 0.9205
# Epoch 97/100
# 24/24 [==============================] - 0s 994us/step - loss: 0.2463 - accuracy: 0.8895
# Epoch 98/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2292 - accuracy: 0.8994
# Epoch 99/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2197 - accuracy: 0.9028
# Epoch 100/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2357 - accuracy: 0.8912

# %% [markdown]
# ## Model Evaluation

# %%
# Evaluate the model using non-linear testing data
model_moon_loss, model_moon_accuracy = nn.evaluate(
    X_moon_test_scaled, y_moon_test, verbose=2
)
print(f"Loss: {model_moon_loss}, Accuracy: {model_moon_accuracy}")
# Out:
# 8/8 - 0s - loss: 0.2182 - accuracy: 0.8840
# Loss: 0.21823707222938538, Accuracy: 0.8840000033378601
