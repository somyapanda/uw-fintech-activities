# %% [markdown]
# # Activating Your First Artificial Neuron

# %%
# Initial imports
import pandas as pd
import numpy as np
from sklearn.datasets import make_blobs, make_moons
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
# %matplotlib inline

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
# ## Using a Single Neuron for Binary Classification
#
# ### Creating Dummy Data

# %%
# Generate 1000 demo data samples with 2 features and two centers
X, y = make_blobs(n_samples=1000, centers=2, n_features=2, random_state=78)

# %%
# Transforming y to a vertical vector
y = y.reshape(-1, 1)
y.shape
# Out:
# (1000, 1)

# %%
# Creating a DataFrame with the dummy data
df = pd.DataFrame(X, columns=['Feature 1', 'Feature 2'])
df['Target'] = y
df.head()
# Out:
#    Feature 1  Feature 2  Target
# 0   5.478098   7.203714       1
# 1  -8.428483   4.121889       0
# 2  -7.905447   3.323639       0
# 3   6.411041   5.523013       1
# 4   7.288599   6.171226       1

# %%
# Plotting the dummy data
df.plot.scatter(x="Feature 1", y="Feature 2", c="Target", colormap="winter")

# %% [markdown]
#  ### Data Preprocessing
#
#  Use `train_test_split` to create training and testing data.

# %%
# Create training and testing datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %% [markdown]
#  Scale the data using the `StandarScaler`.

# %%
# Create scaler instance
X_scaler = StandardScaler()

# %%
# Fit the scaler
X_scaler.fit(X_train)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
#  ### Neural Network Model Creation

# %%
# Create a sequential model
neuron = Sequential()

# %% [markdown]
# The initial step is to add the first layer of our neural network.
#
# ![First Layer](../Images/tensorflow-neuron-layer-1.png)

# %%
# First layer
number_inputs = 2
number_hidden_nodes = 1

neuron.add(Dense(units=number_hidden_nodes, activation="relu", input_dim=number_inputs))

# %% [markdown]
# We finish creating our neural network by adding the output layer.
#
# ![Output layer](../Images/tensorflow-neuron-output-layer.png)

# %%
# Output layer
number_classes = 1

neuron.add(Dense(units=number_classes, activation="sigmoid"))

# %%
# Model summary
neuron.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1)                 3
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 2
# =================================================================
# Total params: 5
# Trainable params: 5
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
#  ### Compile the Model

# %%
# Compile model
neuron.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %% [markdown]
#  ### Fit the Model

# %%
# Fitting the model with linear dummy data
model = neuron.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 1s 2ms/step - loss: 0.5969 - accuracy: 0.9049
# Epoch 2/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5865 - accuracy: 0.9578
# Epoch 3/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5778 - accuracy: 0.9802
# Epoch 4/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5580 - accuracy: 0.9902
# Epoch 5/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5511 - accuracy: 0.9917
# Epoch 6/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5361 - accuracy: 0.9897
# Epoch 7/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5203 - accuracy: 0.9962
# Epoch 8/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5050 - accuracy: 0.9994
# Epoch 9/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4965 - accuracy: 0.9952
# Epoch 10/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4843 - accuracy: 0.9978
# Epoch 11/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4653 - accuracy: 0.9975
# Epoch 12/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4548 - accuracy: 1.0000
# Epoch 13/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4382 - accuracy: 1.0000
# Epoch 14/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4217 - accuracy: 1.0000
# Epoch 15/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4119 - accuracy: 1.0000
# Epoch 16/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3938 - accuracy: 1.0000
# Epoch 17/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3866 - accuracy: 1.0000
# Epoch 18/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3732 - accuracy: 1.0000
# Epoch 19/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3617 - accuracy: 1.0000
# Epoch 20/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3476 - accuracy: 1.0000
# Epoch 21/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3348 - accuracy: 1.0000
# Epoch 22/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3351 - accuracy: 1.0000
# Epoch 23/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3137 - accuracy: 1.0000
# Epoch 24/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3198 - accuracy: 1.0000
# Epoch 25/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3008 - accuracy: 1.0000
# Epoch 26/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3011 - accuracy: 1.0000
# Epoch 27/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2791 - accuracy: 1.0000
# Epoch 28/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2815 - accuracy: 1.0000
# Epoch 29/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2639 - accuracy: 1.0000
# Epoch 30/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2573 - accuracy: 1.0000
# Epoch 31/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2565 - accuracy: 1.0000
# Epoch 32/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2424 - accuracy: 1.0000
# Epoch 33/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2421 - accuracy: 1.0000
# Epoch 34/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2387 - accuracy: 1.0000
# Epoch 35/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2183 - accuracy: 1.0000
# Epoch 36/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2237 - accuracy: 1.0000
# Epoch 37/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2151 - accuracy: 1.0000
# Epoch 38/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2067 - accuracy: 1.0000
# Epoch 39/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2035 - accuracy: 1.0000
# Epoch 40/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2003 - accuracy: 1.0000
# Epoch 41/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2009 - accuracy: 1.0000
# Epoch 42/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1844 - accuracy: 1.0000
# Epoch 43/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1849 - accuracy: 1.0000
# Epoch 44/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1831 - accuracy: 1.0000
# Epoch 45/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1788 - accuracy: 1.0000
# Epoch 46/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1706 - accuracy: 1.0000
# Epoch 47/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1672 - accuracy: 1.0000
# Epoch 48/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1685 - accuracy: 1.0000
# Epoch 49/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1656 - accuracy: 1.0000
# Epoch 50/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1641 - accuracy: 1.0000
# Epoch 51/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1533 - accuracy: 1.0000
# Epoch 52/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1570 - accuracy: 1.0000
# Epoch 53/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1494 - accuracy: 1.0000
# Epoch 54/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1528 - accuracy: 1.0000
# Epoch 55/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1477 - accuracy: 1.0000
# Epoch 56/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1452 - accuracy: 1.0000
# Epoch 57/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1415 - accuracy: 1.0000
# Epoch 58/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1377 - accuracy: 1.0000
# Epoch 59/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1338 - accuracy: 1.0000
# Epoch 60/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1246 - accuracy: 1.0000
# Epoch 61/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1252 - accuracy: 1.0000
# Epoch 62/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1240 - accuracy: 1.0000
# Epoch 63/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1273 - accuracy: 1.0000
# Epoch 64/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1165 - accuracy: 1.0000
# Epoch 65/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1228 - accuracy: 1.0000
# Epoch 66/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1105 - accuracy: 1.0000
# Epoch 67/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1154 - accuracy: 1.0000
# Epoch 68/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1152 - accuracy: 1.0000
# Epoch 69/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1071 - accuracy: 1.0000
# Epoch 70/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1044 - accuracy: 1.0000
# Epoch 71/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1051 - accuracy: 1.0000
# Epoch 72/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1104 - accuracy: 1.0000
# Epoch 73/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1076 - accuracy: 1.0000
# Epoch 74/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1065 - accuracy: 1.0000
# Epoch 75/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.1013 - accuracy: 1.0000
# Epoch 76/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0998 - accuracy: 1.0000
# Epoch 77/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0973 - accuracy: 1.0000
# Epoch 78/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0972 - accuracy: 1.0000
# Epoch 79/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0914 - accuracy: 1.0000
# Epoch 80/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0927 - accuracy: 1.0000
# Epoch 81/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0905 - accuracy: 1.0000
# Epoch 82/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0849 - accuracy: 1.0000
# Epoch 83/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0879 - accuracy: 1.0000
# Epoch 84/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0857 - accuracy: 1.0000
# Epoch 85/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0850 - accuracy: 1.0000
# Epoch 86/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0812 - accuracy: 1.0000
# Epoch 87/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0814 - accuracy: 1.0000
# Epoch 88/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0798 - accuracy: 1.0000
# Epoch 89/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0768 - accuracy: 1.0000
# Epoch 90/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0770 - accuracy: 1.0000
# Epoch 91/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0766 - accuracy: 1.0000
# Epoch 92/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0775 - accuracy: 1.0000
# Epoch 93/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0734 - accuracy: 1.0000
# Epoch 94/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0743 - accuracy: 1.0000
# Epoch 95/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0723 - accuracy: 1.0000
# Epoch 96/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0700 - accuracy: 1.0000
# Epoch 97/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0711 - accuracy: 1.0000
# Epoch 98/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0693 - accuracy: 1.0000
# Epoch 99/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0676 - accuracy: 1.0000
# Epoch 100/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.0670 - accuracy: 1.0000

# %% [markdown]
#  ### Evaluate the Model
#
#  #### Plotting the Loss Function and Accuracy

# %%
# Create a dataframe with the history dictionary
df = pd.DataFrame(model.history, index=range(1, len(model.history["loss"]) + 1))

# Plot the loss
df.plot(y="loss")

# %%
# Plot the accuracy
df.plot(y="accuracy")

# %% [markdown]
#  #### Evaluating the Model Using Testing Data

# %%
# Evaluate the model fit with linear dummy data
model_loss, model_accuracy = neuron.evaluate(X_test_scaled, y_test, verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 8/8 - 0s - loss: 0.0691 - accuracy: 1.0000
# Loss: 0.06909983605146408, Accuracy: 1.0

# %% [markdown]
#  ### Making Predictions with New Data

# %%
# Create 10 new samples of dummy data
new_X, new_y = make_blobs(n_samples=10, centers=2, n_features=2, random_state=78)

# %%
# Making predictions
predictions = neuron.predict_classes(new_X)
results = pd.DataFrame({"predictions": predictions.ravel(), "actual": new_y})
results.head(10)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
#    predictions  actual
# 0            0       0
# 1            1       1
# 2            0       0
# 3            1       1
# 4            0       0
# 5            0       0
# 6            1       1
# 7            1       1
# 8            1       1
# 9            0       0

# %% [markdown]
#  ## Using a Single Neuron for Non-Linear Data
#
#  ### Creating Demo Data

# %%
# Creating dummy non-linear data
X_moons, y_moons = make_moons(n_samples=1000, noise=0.08, random_state=78)

# %%
# Transforming y_moons to a vertical vector
y_moons = y_moons.reshape(-1, 1)

# %%
# Creating a DataFrame to plot the non-linear dummy data
df_moons = pd.DataFrame(X_moons, columns=["Feature 1", "Feature 2"])
df_moons["Target"] = y_moons
df_moons.head()
# Out:
#    Feature 1  Feature 2  Target
# 0   0.676217   0.815220       0
# 1   1.487143  -0.210519       1
# 2  -1.027709   0.354966       0
# 3   0.236012   1.025531       0
# 4   1.856695  -0.042783       1

# %%
# Plotting the non-linear dummy data
df_moons.plot.scatter(x="Feature 1", y="Feature 2", c="Target", colormap="winter")

# %% [markdown]
#  ### Data Preprocessing
#
#  Use `train_test_split` to create training and testing data.

# %%
# Create training and testing sets
X_moon_train, X_moon_test, y_moon_train, y_moon_test = train_test_split(
    X_moons, y_moons, random_state=78
)

# %% [markdown]
#  Scale the data

# %%
# Create the scaler instance
X_moon_scaler = StandardScaler()

# %%
# Fit the scaler
X_moon_scaler.fit(X_moon_train)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
# Scale the data
X_moon_train_scaled = X_moon_scaler.transform(X_moon_train)
X_moon_test_scaled = X_moon_scaler.transform(X_moon_test)

# %% [markdown]
#  ### Fit the Model

# %%
# Training the model with the non-linear data
model_moon = neuron.fit(X_moon_train_scaled, y_moon_train, epochs=100)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7724 - accuracy: 0.6347
# Epoch 2/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.7084 - accuracy: 0.6493
# Epoch 3/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6621 - accuracy: 0.6573
# Epoch 4/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6290 - accuracy: 0.6720
# Epoch 5/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6037 - accuracy: 0.6867
# Epoch 6/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5839 - accuracy: 0.7013
# Epoch 7/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5666 - accuracy: 0.7053
# Epoch 8/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5517 - accuracy: 0.7133
# Epoch 9/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5384 - accuracy: 0.7187
# Epoch 10/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5258 - accuracy: 0.7253
# Epoch 11/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5147 - accuracy: 0.7333
# Epoch 12/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5039 - accuracy: 0.7333
# Epoch 13/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4939 - accuracy: 0.7347
# Epoch 14/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4844 - accuracy: 0.7400
# Epoch 15/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4752 - accuracy: 0.7467
# Epoch 16/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4666 - accuracy: 0.7507
# Epoch 17/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4585 - accuracy: 0.7547
# Epoch 18/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4507 - accuracy: 0.7600
# Epoch 19/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4435 - accuracy: 0.7627
# Epoch 20/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4364 - accuracy: 0.7693
# Epoch 21/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4294 - accuracy: 0.7720
# Epoch 22/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4226 - accuracy: 0.7747
# Epoch 23/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4160 - accuracy: 0.7773
# Epoch 24/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4099 - accuracy: 0.7867
# Epoch 25/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4037 - accuracy: 0.7880
# Epoch 26/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3978 - accuracy: 0.7920
# Epoch 27/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3918 - accuracy: 0.7987
# Epoch 28/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3862 - accuracy: 0.8013
# Epoch 29/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3805 - accuracy: 0.8027
# Epoch 30/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3754 - accuracy: 0.8053
# Epoch 31/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3703 - accuracy: 0.8093
# Epoch 32/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3655 - accuracy: 0.8107
# Epoch 33/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3607 - accuracy: 0.8120
# Epoch 34/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3561 - accuracy: 0.8147
# Epoch 35/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3516 - accuracy: 0.8187
# Epoch 36/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3472 - accuracy: 0.8240
# Epoch 37/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3429 - accuracy: 0.8280
# Epoch 38/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3389 - accuracy: 0.8333
# Epoch 39/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3347 - accuracy: 0.8360
# Epoch 40/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3307 - accuracy: 0.8400
# Epoch 41/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3270 - accuracy: 0.8427
# Epoch 42/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3232 - accuracy: 0.8440
# Epoch 43/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3197 - accuracy: 0.8453
# Epoch 44/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3165 - accuracy: 0.8467
# Epoch 45/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3133 - accuracy: 0.8507
# Epoch 46/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3102 - accuracy: 0.8507
# Epoch 47/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3072 - accuracy: 0.8507
# Epoch 48/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3046 - accuracy: 0.8520
# Epoch 49/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3020 - accuracy: 0.8520
# Epoch 50/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2996 - accuracy: 0.8520
# Epoch 51/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2974 - accuracy: 0.8520
# Epoch 52/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2953 - accuracy: 0.8520
# Epoch 53/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2933 - accuracy: 0.8547
# Epoch 54/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2915 - accuracy: 0.8613
# Epoch 55/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2897 - accuracy: 0.8627
# Epoch 56/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2881 - accuracy: 0.8680
# Epoch 57/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2865 - accuracy: 0.8693
# Epoch 58/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2851 - accuracy: 0.8720
# Epoch 59/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2837 - accuracy: 0.8747
# Epoch 60/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2825 - accuracy: 0.8760
# Epoch 61/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2812 - accuracy: 0.8787
# Epoch 62/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2801 - accuracy: 0.8787
# Epoch 63/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2791 - accuracy: 0.8800
# Epoch 64/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2780 - accuracy: 0.8800
# Epoch 65/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2770 - accuracy: 0.8800
# Epoch 66/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2762 - accuracy: 0.8827
# Epoch 67/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2753 - accuracy: 0.8827
# Epoch 68/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2745 - accuracy: 0.8827
# Epoch 69/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2738 - accuracy: 0.8827
# Epoch 70/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2730 - accuracy: 0.8827
# Epoch 71/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2723 - accuracy: 0.8840
# Epoch 72/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2717 - accuracy: 0.8840
# Epoch 73/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2711 - accuracy: 0.8840
# Epoch 74/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2704 - accuracy: 0.8840
# Epoch 75/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2698 - accuracy: 0.8853
# Epoch 76/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2692 - accuracy: 0.8853
# Epoch 77/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2687 - accuracy: 0.8853
# Epoch 78/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2682 - accuracy: 0.8853
# Epoch 79/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2677 - accuracy: 0.8867
# Epoch 80/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2672 - accuracy: 0.8853
# Epoch 81/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2668 - accuracy: 0.8853
# Epoch 82/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2664 - accuracy: 0.8853
# Epoch 83/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2660 - accuracy: 0.8867
# Epoch 84/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2655 - accuracy: 0.8880
# Epoch 85/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2654 - accuracy: 0.8867
# Epoch 86/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2650 - accuracy: 0.8880
# Epoch 87/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2645 - accuracy: 0.8880
# Epoch 88/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2641 - accuracy: 0.8893
# Epoch 89/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2638 - accuracy: 0.8893
# Epoch 90/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2635 - accuracy: 0.8893
# Epoch 91/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2632 - accuracy: 0.8893
# Epoch 92/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2629 - accuracy: 0.8893
# Epoch 93/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2626 - accuracy: 0.8893
# Epoch 94/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2623 - accuracy: 0.8893
# Epoch 95/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2621 - accuracy: 0.8893
# Epoch 96/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2618 - accuracy: 0.8893
# Epoch 97/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2615 - accuracy: 0.8920
# Epoch 98/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2613 - accuracy: 0.8920
# Epoch 99/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2610 - accuracy: 0.8920
# Epoch 100/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2608 - accuracy: 0.8933

# %% [markdown]
#  ### Evaluate the Model
#
#  #### Plotting the Loss Function and Accuracy

# %%
# Create a dataframe with the history dictionary
df_moon = pd.DataFrame(
    model_moon.history, index=range(1, len(model_moon.history["loss"]) + 1)
)

# Plot the loss
df_moon.plot(y="loss")

# %%
# Plot the accuracy
df_moon.plot(y="accuracy")

# %% [markdown]
#  #### Evaluating the Model Using Testing Data

# %%
# Evaluate the model using non-linear data
model_moon_loss, model_moon_accuracy = neuron.evaluate(
    X_moon_test_scaled, y_moon_test, verbose=2
)
print(f"Loss: {model_moon_loss}, Accuracy: {model_moon_accuracy}")
# Out:
# 8/8 - 0s - loss: 0.2799 - accuracy: 0.8560
# Loss: 0.27991703152656555, Accuracy: 0.8560000061988831

# %% [markdown]
#  ### Making Predictions

# %%
# Create demo data
X_new_moons, y_new_moons = make_moons(n_samples=10, noise=0.08, random_state=78)

# %%
# Making predictions
predictions_moon = neuron.predict_classes(X_new_moons)
results = pd.DataFrame({"predictions": predictions_moon.ravel(), "actual": y_new_moons})
results.head(10)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
#    predictions  actual
# 0            0       0
# 1            0       0
# 2            0       0
# 3            1       1
# 4            1       1
# 5            0       0
# 6            1       0
# 7            1       1
# 8            1       1
# 9            0       1
