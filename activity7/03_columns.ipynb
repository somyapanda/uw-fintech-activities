# %%
import pandas as pd
from pathlib import Path

# %% [markdown]
# Column Manipulation

# %% [markdown]
# Set the file path.

# %%
file_path = "./customers.csv"

# %% [markdown]
# Create a DataFrame from a csv file.

# %%
customers_df = pd.read_csv("./customers.csv")

# %% [markdown]
# Exploring the data

# %% [markdown]
# Get the rows from the data.

# %%
customers_df.head()
# Out:
#           FullName                     Email                  Address    Zip  \
# 0  Altha Frederick  unhideable1966@gmail.com  67 John Maher Extension  31353
# 1  Nickolas Harvey   allgood1803@outlook.com        1200 Madera Plaza   1922
# 2  Jesusita Kinney    satsumas1954@yahoo.com         943 Gibb Highway  41535
# 3      Mose Gordon    antifowl1875@gmail.com          1073 Fell Trace  16098
# 4  Cesar Valentine  acetaminol1979@yahoo.com   805 Marshall Promenade  99895
#
#             CreditCard  Balance
# 0  2524 2317 2139 4751    21511
# 1  4756 0997 9568 1329    13850
# 2    3717 863466 48574    21254
# 3  5413 1700 6989 2835     5221
# 4  5173 4883 9215 4743     8300

# %% [markdown]
# Replace Columns

# %% [markdown]
# Get the columns.

# %%
customers_df.columns
# Out:
# Index(['FullName', 'Email', 'Address', 'Zip', 'CreditCard', 'Balance'], dtype='object')

# %% [markdown]
# Rewrite the column names.

# %%
column_names = ["Full Name", "Email", "Address", "Zip Code", "Credit Card Number", "Account Balance"]
customers_df.columns = column_names
customers_df.head()
# Out:
#          Full Name                     Email                  Address  \
# 0  Altha Frederick  unhideable1966@gmail.com  67 John Maher Extension
# 1  Nickolas Harvey   allgood1803@outlook.com        1200 Madera Plaza
# 2  Jesusita Kinney    satsumas1954@yahoo.com         943 Gibb Highway
# 3      Mose Gordon    antifowl1875@gmail.com          1073 Fell Trace
# 4  Cesar Valentine  acetaminol1979@yahoo.com   805 Marshall Promenade
#
#    Zip Code   Credit Card Number  Account Balance
# 0     31353  2524 2317 2139 4751            21511
# 1      1922  4756 0997 9568 1329            13850
# 2     41535    3717 863466 48574            21254
# 3     16098  5413 1700 6989 2835             5221
# 4     99895  5173 4883 9215 4743             8300

# %% [markdown]
# Rename the Columns

# %%
customers_df = customers_df.rename(columns={
    "Zip Code" : "Zip",
    "Account Balance" : "Balance"
})

customers_df.head()
# Out:
#          Full Name                     Email                  Address    Zip  \
# 0  Altha Frederick  unhideable1966@gmail.com  67 John Maher Extension  31353
# 1  Nickolas Harvey   allgood1803@outlook.com        1200 Madera Plaza   1922
# 2  Jesusita Kinney    satsumas1954@yahoo.com         943 Gibb Highway  41535
# 3      Mose Gordon    antifowl1875@gmail.com          1073 Fell Trace  16098
# 4  Cesar Valentine  acetaminol1979@yahoo.com   805 Marshall Promenade  99895
#
#     Credit Card Number  Balance
# 0  2524 2317 2139 4751    21511
# 1  4756 0997 9568 1329    13850
# 2    3717 863466 48574    21254
# 3  5413 1700 6989 2835     5221
# 4  5173 4883 9215 4743     8300

# %% [markdown]
# Reorder Columns

# %%
customers_df = customers_df[["Full Name", "Address", "Credit Card Number", "Email", "Zip", "Balance"]]
customers_df.head()
# Out:
#          Full Name                  Address   Credit Card Number  \
# 0  Altha Frederick  67 John Maher Extension  2524 2317 2139 4751
# 1  Nickolas Harvey        1200 Madera Plaza  4756 0997 9568 1329
# 2  Jesusita Kinney         943 Gibb Highway    3717 863466 48574
# 3      Mose Gordon          1073 Fell Trace  5413 1700 6989 2835
# 4  Cesar Valentine   805 Marshall Promenade  5173 4883 9215 4743
#
#                       Email    Zip  Balance
# 0  unhideable1966@gmail.com  31353    21511
# 1   allgood1803@outlook.com   1922    13850
# 2    satsumas1954@yahoo.com  41535    21254
# 3    antifowl1875@gmail.com  16098     5221
# 4  acetaminol1979@yahoo.com  99895     8300

# %% [markdown]
# Create new columns

# %%
customers_df["Balance (1k)"] = customers_df["Balance"] / 1000
customers_df.head()
# Out:
#          Full Name                  Address   Credit Card Number  \
# 0  Altha Frederick  67 John Maher Extension  2524 2317 2139 4751
# 1  Nickolas Harvey        1200 Madera Plaza  4756 0997 9568 1329
# 2  Jesusita Kinney         943 Gibb Highway    3717 863466 48574
# 3      Mose Gordon          1073 Fell Trace  5413 1700 6989 2835
# 4  Cesar Valentine   805 Marshall Promenade  5173 4883 9215 4743
#
#                       Email    Zip  Balance  Balance (1k)
# 0  unhideable1966@gmail.com  31353    21511        21.511
# 1   allgood1803@outlook.com   1922    13850        13.850
# 2    satsumas1954@yahoo.com  41535    21254        21.254
# 3    antifowl1875@gmail.com  16098     5221         5.221
# 4  acetaminol1979@yahoo.com  99895     8300         8.300

# %% [markdown]
# Split the columns

# %%
customer_names = customers_df["Full Name"].str.split(" ", expand=True)
customer_names.head()
# Out:
#           0          1
# 0     Altha  Frederick
# 1  Nickolas     Harvey
# 2  Jesusita     Kinney
# 3      Mose     Gordon
# 4     Cesar  Valentine

# %%
customers_df["First Name"] = customer_names[0]
customers_df["Last Name"] = customer_names[1]
customers_df.head()
# Out:
#          Full Name                  Address   Credit Card Number  \
# 0  Altha Frederick  67 John Maher Extension  2524 2317 2139 4751
# 1  Nickolas Harvey        1200 Madera Plaza  4756 0997 9568 1329
# 2  Jesusita Kinney         943 Gibb Highway    3717 863466 48574
# 3      Mose Gordon          1073 Fell Trace  5413 1700 6989 2835
# 4  Cesar Valentine   805 Marshall Promenade  5173 4883 9215 4743
#
#                       Email    Zip  Balance  Balance (1k) First Name  \
# 0  unhideable1966@gmail.com  31353    21511        21.511      Altha
# 1   allgood1803@outlook.com   1922    13850        13.850   Nickolas
# 2    satsumas1954@yahoo.com  41535    21254        21.254   Jesusita
# 3    antifowl1875@gmail.com  16098     5221         5.221       Mose
# 4  acetaminol1979@yahoo.com  99895     8300         8.300      Cesar
#
#    Last Name
# 0  Frederick
# 1     Harvey
# 2     Kinney
# 3     Gordon
# 4  Valentine

# %% [markdown]
# Delete columns

# %%
customers_df = customers_df.drop(columns=["Full Name"])
customers_df.head()
# Out:
#                    Address   Credit Card Number                     Email  \
# 0  67 John Maher Extension  2524 2317 2139 4751  unhideable1966@gmail.com
# 1        1200 Madera Plaza  4756 0997 9568 1329   allgood1803@outlook.com
# 2         943 Gibb Highway    3717 863466 48574    satsumas1954@yahoo.com
# 3          1073 Fell Trace  5413 1700 6989 2835    antifowl1875@gmail.com
# 4   805 Marshall Promenade  5173 4883 9215 4743  acetaminol1979@yahoo.com
#
#      Zip  Balance  Balance (1k) First Name  Last Name
# 0  31353    21511        21.511      Altha  Frederick
# 1   1922    13850        13.850   Nickolas     Harvey
# 2  41535    21254        21.254   Jesusita     Kinney
# 3  16098     5221         5.221       Mose     Gordon
# 4  99895     8300         8.300      Cesar  Valentine
