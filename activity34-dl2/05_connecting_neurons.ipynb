# %%
# !pip install hvplot
# Out:
# Collecting hvplot
#   Downloading https://files.pythonhosted.org/packages/98/18/6c5b3b91639fb6d266ba0d6ce29e798bfe5429fd699d7725b7f79dcdccd8/hvplot-0.7.1-py2.py3-none-any.whl (3.1MB)
#      |████████████████████████████████| 3.1MB 6.5MB/s
# Requirement already satisfied: colorcet>=2 in /usr/local/lib/python3.7/dist-packages (from hvplot) (2.0.6)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from hvplot) (1.19.5)
# Requirement already satisfied: bokeh>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from hvplot) (2.3.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from hvplot) (1.1.5)
# Requirement already satisfied: holoviews>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from hvplot) (1.14.3)
# Requirement already satisfied: param>=1.7.0 in /usr/local/lib/python3.7/dist-packages (from colorcet>=2->hvplot) (1.10.1)
# Requirement already satisfied: pyct>=0.4.4 in /usr/local/lib/python3.7/dist-packages (from colorcet>=2->hvplot) (0.4.8)
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.7/dist-packages (from bokeh>=1.0.0->hvplot) (7.1.2)
# Requirement already satisfied: packaging>=16.8 in /usr/local/lib/python3.7/dist-packages (from bokeh>=1.0.0->hvplot) (20.9)
# Requirement already satisfied: tornado>=5.1 in /usr/local/lib/python3.7/dist-packages (from bokeh>=1.0.0->hvplot) (5.1.1)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from bokeh>=1.0.0->hvplot) (2.8.1)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.7/dist-packages (from bokeh>=1.0.0->hvplot) (3.13)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from bokeh>=1.0.0->hvplot) (3.7.4.3)
# Requirement already satisfied: Jinja2>=2.9 in /usr/local/lib/python3.7/dist-packages (from bokeh>=1.0.0->hvplot) (2.11.3)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->hvplot) (2018.9)
# Requirement already satisfied: pyviz-comms>=0.7.4 in /usr/local/lib/python3.7/dist-packages (from holoviews>=1.11.0->hvplot) (2.0.1)
# Requirement already satisfied: panel>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from holoviews>=1.11.0->hvplot) (0.11.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=16.8->bokeh>=1.0.0->hvplot) (2.4.7)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.1->bokeh>=1.0.0->hvplot) (1.15.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2>=2.9->bokeh>=1.0.0->hvplot) (2.0.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from panel>=0.8.0->holoviews>=1.11.0->hvplot) (2.23.0)
# Requirement already satisfied: markdown in /usr/local/lib/python3.7/dist-packages (from panel>=0.8.0->holoviews>=1.11.0->hvplot) (3.3.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from panel>=0.8.0->holoviews>=1.11.0->hvplot) (4.41.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->panel>=0.8.0->holoviews>=1.11.0->hvplot) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->panel>=0.8.0->holoviews>=1.11.0->hvplot) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->panel>=0.8.0->holoviews>=1.11.0->hvplot) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->panel>=0.8.0->holoviews>=1.11.0->hvplot) (1.24.3)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from markdown->panel>=0.8.0->holoviews>=1.11.0->hvplot) (4.0.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown->panel>=0.8.0->holoviews>=1.11.0->hvplot) (3.4.1)
# Installing collected packages: hvplot
# Successfully installed hvplot-0.7.1

# %%
# Initial imports
import pandas as pd
import numpy as np
import hvplot.pandas
import holoviews as hv
from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # Instructor Do: Connecting Neurons

# %% [markdown]
# ## Creating Dummy Data

# %%
# Creating dummy non-linear data
X_moons, y_moons = make_moons(n_samples=1000, noise=0.08, random_state=78)

# %%
# Transforming y_moons to a vertical vector
y_moons = y_moons.reshape(-1, 1)

# %%
# Creating a DataFrame to plot the non-linear dummy data
df_moons = pd.DataFrame(X_moons, columns=["Feature 1", "Feature 2"])
df_moons["Target"] = y_moons
df_moons.head()
# Out:
#    Feature 1  Feature 2  Target
# 0   0.676217   0.815220       0
# 1   1.487143  -0.210519       1
# 2  -1.027709   0.354966       0
# 3   0.236012   1.025531       0
# 4   1.856695  -0.042783       1

# %%
# Plotting the non-linear dummy data

hv.extension("bokeh")
plot = df_moons.hvplot.scatter(x="Feature 1", y="Feature 2", by="Target")
plot
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ## Data Preprocessing

# %%
# Create training and testing sets
X_moon_train, X_moon_test, y_moon_train, y_moon_test = train_test_split(
    X_moons, y_moons, random_state=78
)

# %%
# Create the scaler instance
X_moon_scaler = StandardScaler()

# %%
# Fit the scaler
X_moon_scaler.fit(X_moon_train)
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
# Scale the data
X_moon_train_scaled = X_moon_scaler.transform(X_moon_train)
X_moon_test_scaled = X_moon_scaler.transform(X_moon_test)

# %% [markdown]
# ## Neural Network Model Creation

# %%
# Create the sequential model
nn = Sequential()

# %% [markdown]
# ### Fisrt Layer

# %%
# First layer
number_inputs = 2
number_hidden_nodes = 6

nn.add(Dense(units=number_hidden_nodes, activation="relu", input_dim=number_inputs))

# %% [markdown]
# ### Output Layer

# %%
# Output layer
number_classes = 1

nn.add(Dense(units=number_classes, activation="sigmoid"))

# %%
# Model summary
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 6)                 18
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 7
# =================================================================
# Total params: 25
# Trainable params: 25
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Compile the Model

# %%
# Compile model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %% [markdown]
# ## Fit the Model

# %%
# Training the model with the non-linear data
model_moon = nn.fit(X_moon_train_scaled, y_moon_train, epochs=100)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 1s 1ms/step - loss: 0.6210 - accuracy: 0.4959
# Epoch 2/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.6148 - accuracy: 0.4802
# Epoch 3/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5997 - accuracy: 0.5439
# Epoch 4/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5636 - accuracy: 0.5915
# Epoch 5/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5491 - accuracy: 0.7213
# Epoch 6/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5334 - accuracy: 0.7741
# Epoch 7/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5203 - accuracy: 0.7894
# Epoch 8/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.5105 - accuracy: 0.8022
# Epoch 9/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4989 - accuracy: 0.8075
# Epoch 10/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4859 - accuracy: 0.8309
# Epoch 11/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4770 - accuracy: 0.8271
# Epoch 12/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4468 - accuracy: 0.8624
# Epoch 13/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4512 - accuracy: 0.8484
# Epoch 14/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4288 - accuracy: 0.8735
# Epoch 15/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4220 - accuracy: 0.8831
# Epoch 16/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.4232 - accuracy: 0.8513
# Epoch 17/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4031 - accuracy: 0.8783
# Epoch 18/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3858 - accuracy: 0.8954
# Epoch 19/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3765 - accuracy: 0.8749
# Epoch 20/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3782 - accuracy: 0.8641
# Epoch 21/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3399 - accuracy: 0.8899
# Epoch 22/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3424 - accuracy: 0.8850
# Epoch 23/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3285 - accuracy: 0.8979
# Epoch 24/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3103 - accuracy: 0.8956
# Epoch 25/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3143 - accuracy: 0.8959
# Epoch 26/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3154 - accuracy: 0.8874
# Epoch 27/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3158 - accuracy: 0.8809
# Epoch 28/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2885 - accuracy: 0.8989
# Epoch 29/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.3028 - accuracy: 0.8887
# Epoch 30/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2822 - accuracy: 0.8874
# Epoch 31/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2858 - accuracy: 0.8829
# Epoch 32/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2825 - accuracy: 0.8833
# Epoch 33/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2800 - accuracy: 0.8937
# Epoch 34/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2777 - accuracy: 0.8824
# Epoch 35/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2757 - accuracy: 0.8891
# Epoch 36/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2571 - accuracy: 0.9014
# Epoch 37/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2755 - accuracy: 0.8852
# Epoch 38/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2828 - accuracy: 0.8891
# Epoch 39/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2377 - accuracy: 0.9026
# Epoch 40/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2663 - accuracy: 0.8887
# Epoch 41/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2604 - accuracy: 0.8895
# Epoch 42/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2714 - accuracy: 0.8910
# Epoch 43/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2746 - accuracy: 0.8884
# Epoch 44/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2808 - accuracy: 0.8863
# Epoch 45/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2597 - accuracy: 0.8997
# Epoch 46/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2494 - accuracy: 0.8997
# Epoch 47/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2551 - accuracy: 0.8885
# Epoch 48/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2658 - accuracy: 0.8926
# Epoch 49/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2297 - accuracy: 0.9053
# Epoch 50/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2480 - accuracy: 0.9037
# Epoch 51/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2378 - accuracy: 0.9012
# Epoch 52/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2518 - accuracy: 0.8993
# Epoch 53/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2675 - accuracy: 0.8945
# Epoch 54/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2457 - accuracy: 0.9052
# Epoch 55/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2442 - accuracy: 0.8992
# Epoch 56/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2575 - accuracy: 0.8834
# Epoch 57/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2326 - accuracy: 0.9038
# Epoch 58/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2421 - accuracy: 0.9007
# Epoch 59/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2690 - accuracy: 0.8810
# Epoch 60/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2606 - accuracy: 0.8880
# Epoch 61/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2484 - accuracy: 0.8924
# Epoch 62/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2346 - accuracy: 0.8949
# Epoch 63/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2375 - accuracy: 0.9051
# Epoch 64/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2426 - accuracy: 0.9021
# Epoch 65/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2264 - accuracy: 0.9133
# Epoch 66/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2486 - accuracy: 0.8944
# Epoch 67/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2611 - accuracy: 0.8798
# Epoch 68/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2569 - accuracy: 0.8841
# Epoch 69/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2184 - accuracy: 0.9084
# Epoch 70/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2420 - accuracy: 0.9008
# Epoch 71/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2216 - accuracy: 0.9099
# Epoch 72/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2650 - accuracy: 0.8761
# Epoch 73/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2683 - accuracy: 0.8849
# Epoch 74/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2384 - accuracy: 0.9029
# Epoch 75/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2402 - accuracy: 0.8999
# Epoch 76/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2791 - accuracy: 0.8780
# Epoch 77/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2260 - accuracy: 0.9033
# Epoch 78/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2637 - accuracy: 0.8783
# Epoch 79/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2506 - accuracy: 0.8939
# Epoch 80/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2245 - accuracy: 0.9106
# Epoch 81/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2466 - accuracy: 0.8922
# Epoch 82/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2539 - accuracy: 0.8949
# Epoch 83/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2298 - accuracy: 0.9039
# Epoch 84/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2522 - accuracy: 0.8932
# Epoch 85/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2168 - accuracy: 0.9142
# Epoch 86/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2254 - accuracy: 0.9015
# Epoch 87/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2269 - accuracy: 0.9062
# Epoch 88/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2402 - accuracy: 0.8960
# Epoch 89/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2826 - accuracy: 0.8752
# Epoch 90/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2359 - accuracy: 0.8963
# Epoch 91/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2198 - accuracy: 0.9001
# Epoch 92/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2461 - accuracy: 0.9022
# Epoch 93/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2804 - accuracy: 0.8771
# Epoch 94/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2434 - accuracy: 0.8882
# Epoch 95/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2113 - accuracy: 0.9080
# Epoch 96/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2504 - accuracy: 0.8899
# Epoch 97/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2547 - accuracy: 0.8863
# Epoch 98/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2258 - accuracy: 0.8976
# Epoch 99/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2390 - accuracy: 0.8894
# Epoch 100/100
# 24/24 [==============================] - 0s 1ms/step - loss: 0.2076 - accuracy: 0.9156

# %% [markdown]
# ## Model Evaluation

# %%
# Evaluate the model using non-linear testing data
model_moon_loss, model_moon_accuracy = nn.evaluate(
    X_moon_test_scaled, y_moon_test, verbose=2
)
print(f"Loss: {model_moon_loss}, Accuracy: {model_moon_accuracy}")
# Out:
# 8/8 - 0s - loss: 0.2579 - accuracy: 0.8600
# Loss: 0.257921427488327, Accuracy: 0.8600000143051147
