# %% [markdown]
# # Create and Deploy a Machine Learning Model in Amazon SageMaker

# %%
# Initial imports
import os
import io
import json
import numpy as np
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score


# Amazon SageMaker and related imports
import sagemaker
import sagemaker.amazon.common as smac
from sagemaker.predictor import csv_serializer, json_deserializer
from sagemaker import get_execution_role
from sagemaker.amazon.amazon_estimator import get_image_uri
import boto3  # AWS Python sdk

# %matplotlib inline

# %% [markdown]
# ## Reading Data

# %%
# Read the weather features data
file_path = Path("Data/x_austin_final.csv")
features = pd.read_csv(file_path)

# Transforming the "TempAvgF" column to a vector
X = features["TempAvgF"].values.reshape(-1, 1)

# %%
# Read the target data (precipitation sum inches)
file_path = Path("Data/y_austin_final.csv")
y = pd.read_csv(file_path, names=["PrecipitationSumInches"], header=None)

# Transforming y into a vector
y = y.iloc[:, 0].values

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# ## Creating the Linear Regression Model
# ### Initial Configurations

# %%
# Define Amazon S3 Bucket to store model data
bucket = "sagemaker-20210508-1207"  

# Define prefix for data files
prefix = "austin-rainfall-regression"

# AWS IAM role
role = get_execution_role()

# %% [markdown]
# ## Uploading Training Data to Amazon S3

# %%
# Encode the training data as Protocol Buffer
buf = io.BytesIO()
vectors = np.array(X_train).astype("float32")
labels = np.array(y_train).astype("float32")
smac.write_numpy_to_dense_tensor(buf, vectors, labels)
buf.seek(0)

# Upload encoded training data to Amazon S3
key = "linear_train.data"
boto3.resource("s3").Bucket(bucket).Object(
    os.path.join(prefix, "train", key)
).upload_fileobj(buf)
s3_train_data = "s3://{}/{}/train/{}".format(bucket, prefix, key)
print("Training data uploaded to: {}".format(s3_train_data))
# Out:
# Training data uploaded to: s3://sagemaker-20210508-1207/austin-rainfall-regression/train/linear_train.data

# %% [markdown]
# ## Upload Test Data to Amazon S3

# %%
# Encode the testing data as Protocol Buffer
buf = io.BytesIO()
vectors = np.array(X_test).astype("float32")
labels = np.array(y_test).astype("float32")
smac.write_numpy_to_dense_tensor(buf, vectors, labels)
buf.seek(0)

# Upload encoded testing data to Amazon S3
key = "linear_test.data"
boto3.resource("s3").Bucket(bucket).Object(
    os.path.join(prefix, "test", key)
).upload_fileobj(buf)
s3_test_data = "s3://{}/{}/test/{}".format(bucket, prefix, key)
print("Testing data uploaded to: {}".format(s3_test_data))
# Out:
# Testing data uploaded to: s3://sagemaker-20210508-1207/austin-rainfall-regression/test/linear_test.data

# %% [markdown]
# ### Creating Model Instance

# %%
# Create an instance of the linear learner algorithm
container = get_image_uri(boto3.Session().region_name, "linear-learner")
# Out:
# The method get_image_uri has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.

# %%
# Start the Amazon SageMaker session
sess = sagemaker.Session()

# Create an instance of the linear learner estimator
linear = sagemaker.estimator.Estimator(
    container,
    role,
    train_instance_count=1,
    train_instance_type="ml.m4.xlarge",
    output_path="s3://{}/{}/output".format(bucket, prefix),
    sagemaker_session=sess,
)

# Define linear learner hyperparameters
linear.set_hyperparameters(
    feature_dim=1,
    mini_batch_size=100,
    predictor_type="regressor",
    epochs=10,
    num_models=32,
    loss="absolute_loss",
)
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %% [markdown]
# ## Training the Machine Learning Model

# %%
# Fitting the linear learner model with the training data
linear.fit({"train": s3_train_data, "test": s3_test_data})
# Out:
# 2021-05-08 19:08:47 Starting - Starting the training job...
# 2021-05-08 19:08:49 Starting - Launching requested ML instancesProfilerReport-1620500927: InProgress
# ......
# 2021-05-08 19:10:03 Starting - Preparing the instances for training......
# 2021-05-08 19:11:18 Downloading - Downloading input data
# 2021-05-08 19:11:18 Training - Downloading the training image.....Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [05/08/2021 19:11:55 INFO 139703712118592] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/resources/default-input.json: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false'}
# [05/08/2021 19:11:55 INFO 139703712118592] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'loss': 'absolute_loss', 'feature_dim': '1', 'num_models': '32', 'predictor_type': 'regressor', 'epochs': '10', 'mini_batch_size': '100'}
# [05/08/2021 19:11:55 INFO 139703712118592] Final configuration: {'mini_batch_size': '100', 'epochs': '10', 'feature_dim': '1', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': '32', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'absolute_loss', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'regressor'}
# [05/08/2021 19:11:55 WARNING 139703712118592] Loggers have already been setup.
# Process 1 is a worker.
# [05/08/2021 19:11:55 INFO 139703712118592] Using default worker.
# [05/08/2021 19:11:56 INFO 139703712118592] Checkpoint loading and saving are disabled.
# [2021-05-08 19:11:56.216] [tensorio] [warning] TensorIO is already initialized; ignoring the initialization routine.
# [2021-05-08 19:11:56.233] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 17, "num_examples": 1, "num_bytes": 4800}
# [05/08/2021 19:11:56 INFO 139703712118592] Create Store: local
# [2021-05-08 19:11:56.329] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 95, "num_examples": 11, "num_bytes": 50640}
# [05/08/2021 19:11:56 INFO 139703712118592] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f0eee947850>
# [05/08/2021 19:11:56 INFO 139703712118592] Scaling model computed with parameters:
#  {'stdev_label':
# [0.42651978]
# <NDArray 1 @cpu(0)>, 'stdev_weight':
# [14.252788]
# <NDArray 1 @cpu(0)>, 'mean_label':
# [0.11147]
# <NDArray 1 @cpu(0)>, 'mean_weight':
# [70.65501]
# <NDArray 1 @cpu(0)>}
# [05/08/2021 19:11:56 INFO 139703712118592] nvidia-smi: took 0.031 seconds to run.
# [05/08/2021 19:11:56 INFO 139703712118592] nvidia-smi identified 0 GPUs.
# [05/08/2021 19:11:56 INFO 139703712118592] Number of GPUs being used: 0
# #metrics {"StartTime": 1620501116.4455113, "EndTime": 1620501116.4455528, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 1155.0, "count": 1, "min": 1155, "max": 1155}, "Total Batches Seen": {"sum": 12.0, "count": 1, "min": 12, "max": 12}, "Max Records Seen Between Resets": {"sum": 1055.0, "count": 1, "min": 1055, "max": 1055}, "Max Batches Seen Between Resets": {"sum": 11.0, "count": 1, "min": 11, "max": 11}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# [2021-05-08 19:11:56.706] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 4, "duration": 260, "num_examples": 11, "num_bytes": 50640}
# #metrics {"StartTime": 1620501116.7061162, "EndTime": 1620501116.7062032, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 0}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3333560752868652, "count": 1, "min": 0.3333560752868652, "max": 0.3333560752868652}}}
#
# #metrics {"StartTime": 1620501116.7063017, "EndTime": 1620501116.7063239, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 1}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3284783706665039, "count": 1, "min": 0.3284783706665039, "max": 0.3284783706665039}}}
#
# #metrics {"StartTime": 1620501116.7063818, "EndTime": 1620501116.7063987, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 2}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3333284854888916, "count": 1, "min": 0.3333284854888916, "max": 0.3333284854888916}}}
#
# #metrics {"StartTime": 1620501116.7064507, "EndTime": 1620501116.7064672, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 3}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.32820600318908694, "count": 1, "min": 0.32820600318908694, "max": 0.32820600318908694}}}
#
# #metrics {"StartTime": 1620501116.7065217, "EndTime": 1620501116.7065392, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 4}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.6055654792785644, "count": 1, "min": 0.6055654792785644, "max": 0.6055654792785644}}}
#
# #metrics {"StartTime": 1620501116.7065935, "EndTime": 1620501116.7066095, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 5}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.6027858428955079, "count": 1, "min": 0.6027858428955079, "max": 0.6027858428955079}}}
#
# #metrics {"StartTime": 1620501116.7066636, "EndTime": 1620501116.7066813, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 6}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.6024050540924072, "count": 1, "min": 0.6024050540924072, "max": 0.6024050540924072}}}
#
# #metrics {"StartTime": 1620501116.7067356, "EndTime": 1620501116.7067533, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 7}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.5995382614135742, "count": 1, "min": 0.5995382614135742, "max": 0.5995382614135742}}}
#
# #metrics {"StartTime": 1620501116.7068062, "EndTime": 1620501116.7068229, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 8}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3358445110321045, "count": 1, "min": 0.3358445110321045, "max": 0.3358445110321045}}}
#
# #metrics {"StartTime": 1620501116.7068777, "EndTime": 1620501116.7068942, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 9}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3335285110473633, "count": 1, "min": 0.3335285110473633, "max": 0.3335285110473633}}}
#
# #metrics {"StartTime": 1620501116.706948, "EndTime": 1620501116.706966, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 10}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.333417121887207, "count": 1, "min": 0.333417121887207, "max": 0.333417121887207}}}
#
# #metrics {"StartTime": 1620501116.707021, "EndTime": 1620501116.7070377, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 11}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3318645534515381, "count": 1, "min": 0.3318645534515381, "max": 0.3318645534515381}}}
#
# #metrics {"StartTime": 1620501116.7070954, "EndTime": 1620501116.7071114, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 12}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.6026766185760498, "count": 1, "min": 0.6026766185760498, "max": 0.6026766185760498}}}
#
# #metrics {"StartTime": 1620501116.7071662, "EndTime": 1620501116.707182, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 13}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.6044642066955567, "count": 1, "min": 0.6044642066955567, "max": 0.6044642066955567}}}
#
# #metrics {"StartTime": 1620501116.707238, "EndTime": 1620501116.7072542, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 14}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.6025753669738769, "count": 1, "min": 0.6025753669738769, "max": 0.6025753669738769}}}
#
# #metrics {"StartTime": 1620501116.7073095, "EndTime": 1620501116.707326, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 15}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.6048926239013672, "count": 1, "min": 0.6048926239013672, "max": 0.6048926239013672}}}
#
# #metrics {"StartTime": 1620501116.707382, "EndTime": 1620501116.707399, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 16}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.33083285903930665, "count": 1, "min": 0.33083285903930665, "max": 0.33083285903930665}}}
#
# #metrics {"StartTime": 1620501116.7074547, "EndTime": 1620501116.7074718, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 17}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.32863594245910643, "count": 1, "min": 0.32863594245910643, "max": 0.32863594245910643}}}
#
# #metrics {"StartTime": 1620501116.7075284, "EndTime": 1620501116.7075455, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 18}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.33348196220397947, "count": 1, "min": 0.33348196220397947, "max": 0.33348196220397947}}}
#
# #metrics {"StartTime": 1620501116.7075999, "EndTime": 1620501116.7076159, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 19}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3335306224822998, "count": 1, "min": 0.3335306224822998, "max": 0.3335306224822998}}}
#
# #metrics {"StartTime": 1620501116.70766, "EndTime": 1620501116.707675, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 20}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.6884158229827881, "count": 1, "min": 0.6884158229827881, "max": 0.6884158229827881}}}
#
# #metrics {"StartTime": 1620501116.707722, "EndTime": 1620501116.7077367, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 21}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.6927189674377442, "count": 1, "min": 0.6927189674377442, "max": 0.6927189674377442}}}
#
# #metrics {"StartTime": 1620501116.7077854, "EndTime": 1620501116.7078001, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 22}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.6034164562225341, "count": 1, "min": 0.6034164562225341, "max": 0.6034164562225341}}}
#
# #metrics {"StartTime": 1620501116.7078454, "EndTime": 1620501116.70786, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 23}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.6878612880706787, "count": 1, "min": 0.6878612880706787, "max": 0.6878612880706787}}}
#
# #metrics {"StartTime": 1620501116.707911, "EndTime": 1620501116.7079265, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 24}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3356121940612793, "count": 1, "min": 0.3356121940612793, "max": 0.3356121940612793}}}
#
# #metrics {"StartTime": 1620501116.707978, "EndTime": 1620501116.707993, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 25}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.33286174392700196, "count": 1, "min": 0.33286174392700196, "max": 0.33286174392700196}}}
#
# #metrics {"StartTime": 1620501116.708048, "EndTime": 1620501116.7080653, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 26}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.33295621490478516, "count": 1, "min": 0.33295621490478516, "max": 0.33295621490478516}}}
#
# #metrics {"StartTime": 1620501116.7081165, "EndTime": 1620501116.7081275, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 27}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3331028232574463, "count": 1, "min": 0.3331028232574463, "max": 0.3331028232574463}}}
#
# #metrics {"StartTime": 1620501116.7081594, "EndTime": 1620501116.7081735, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 28}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7143751049041748, "count": 1, "min": 0.7143751049041748, "max": 0.7143751049041748}}}
#
# #metrics {"StartTime": 1620501116.7082248, "EndTime": 1620501116.7082415, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 29}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.7144521923065186, "count": 1, "min": 0.7144521923065186, "max": 0.7144521923065186}}}
#
# #metrics {"StartTime": 1620501116.708292, "EndTime": 1620501116.7083025, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 30}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.6667162857055664, "count": 1, "min": 0.6667162857055664, "max": 0.6667162857055664}}}
#
# #metrics {"StartTime": 1620501116.7083547, "EndTime": 1620501116.708371, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 31}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.6319377861022949, "count": 1, "min": 0.6319377861022949, "max": 0.6319377861022949}}}
#
# [05/08/2021 19:11:56 INFO 139703712118592] #quality_metric: host=algo-1, epoch=0, train absolute_loss_objective <loss>=0.3333560752868652
# [05/08/2021 19:11:56 INFO 139703712118592] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=absolute_loss_objective, value=0.32820600318908694
# [05/08/2021 19:11:56 INFO 139703712118592] Epoch 0: Loss improved. Updating best model
# [05/08/2021 19:11:56 INFO 139703712118592] Saving model for epoch: 0
# [05/08/2021 19:11:56 INFO 139703712118592] Saved checkpoint to "/tmp/tmp_46youak/mx-mod-0000.params"
# [05/08/2021 19:11:56 INFO 139703712118592] #progress_metric: host=algo-1, completed 10.0 % of epochs
# #metrics {"StartTime": 1620501116.4458318, "EndTime": 1620501116.7232926, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 2210.0, "count": 1, "min": 2210, "max": 2210}, "Total Batches Seen": {"sum": 23.0, "count": 1, "min": 23, "max": 23}, "Max Records Seen Between Resets": {"sum": 1055.0, "count": 1, "min": 1055, "max": 1055}, "Max Batches Seen Between Resets": {"sum": 11.0, "count": 1, "min": 11, "max": 11}, "Reset Count": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Number of Records Since Last Reset": {"sum": 1055.0, "count": 1, "min": 1055, "max": 1055}, "Number of Batches Since Last Reset": {"sum": 11.0, "count": 1, "min": 11, "max": 11}}}
#
# [05/08/2021 19:11:56 INFO 139703712118592] #throughput_metric: host=algo-1, train throughput=3800.395688581612 records/second
# [2021-05-08 19:11:57.003] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 6, "duration": 279, "num_examples": 11, "num_bytes": 50640}
# #metrics {"StartTime": 1620501117.0033095, "EndTime": 1620501117.003406, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2897264394760132, "count": 1, "min": 0.2897264394760132, "max": 0.2897264394760132}}}
#
# #metrics {"StartTime": 1620501117.0035193, "EndTime": 1620501117.0035443, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2820224123001099, "count": 1, "min": 0.2820224123001099, "max": 0.2820224123001099}}}
#
# #metrics {"StartTime": 1620501117.003607, "EndTime": 1620501117.0036256, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2894074115753174, "count": 1, "min": 0.2894074115753174, "max": 0.2894074115753174}}}
#
# #metrics {"StartTime": 1620501117.0036845, "EndTime": 1620501117.0037029, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2824324331283569, "count": 1, "min": 0.2824324331283569, "max": 0.2824324331283569}}}
#
# #metrics {"StartTime": 1620501117.0037544, "EndTime": 1620501117.003771, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.4705259914398193, "count": 1, "min": 0.4705259914398193, "max": 0.4705259914398193}}}
#
# #metrics {"StartTime": 1620501117.003829, "EndTime": 1620501117.0038462, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.403845609664917, "count": 1, "min": 0.403845609664917, "max": 0.403845609664917}}}
#
# #metrics {"StartTime": 1620501117.003904, "EndTime": 1620501117.0039213, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 6}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3845403003692627, "count": 1, "min": 0.3845403003692627, "max": 0.3845403003692627}}}
#
# #metrics {"StartTime": 1620501117.0039754, "EndTime": 1620501117.0039935, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 7}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.4060293388366699, "count": 1, "min": 0.4060293388366699, "max": 0.4060293388366699}}}
#
# #metrics {"StartTime": 1620501117.0040486, "EndTime": 1620501117.0040662, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 8}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.28844553661346434, "count": 1, "min": 0.28844553661346434, "max": 0.28844553661346434}}}
#
# #metrics {"StartTime": 1620501117.0041232, "EndTime": 1620501117.0041404, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 9}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.29210413837432864, "count": 1, "min": 0.29210413837432864, "max": 0.29210413837432864}}}
#
# #metrics {"StartTime": 1620501117.0041952, "EndTime": 1620501117.0042117, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 10}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2913459157943726, "count": 1, "min": 0.2913459157943726, "max": 0.2913459157943726}}}
#
# #metrics {"StartTime": 1620501117.0042672, "EndTime": 1620501117.0042837, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 11}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.28277221870422364, "count": 1, "min": 0.28277221870422364, "max": 0.28277221870422364}}}
#
# #metrics {"StartTime": 1620501117.004338, "EndTime": 1620501117.0043557, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 12}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3834610233306885, "count": 1, "min": 0.3834610233306885, "max": 0.3834610233306885}}}
#
# #metrics {"StartTime": 1620501117.0044158, "EndTime": 1620501117.0044322, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 13}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.46927062606811526, "count": 1, "min": 0.46927062606811526, "max": 0.46927062606811526}}}
#
# #metrics {"StartTime": 1620501117.004488, "EndTime": 1620501117.0045047, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 14}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.43782089614868164, "count": 1, "min": 0.43782089614868164, "max": 0.43782089614868164}}}
#
# #metrics {"StartTime": 1620501117.0045648, "EndTime": 1620501117.0045826, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 15}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.47103191184997556, "count": 1, "min": 0.47103191184997556, "max": 0.47103191184997556}}}
#
# #metrics {"StartTime": 1620501117.0046368, "EndTime": 1620501117.004654, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 16}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2812215042114258, "count": 1, "min": 0.2812215042114258, "max": 0.2812215042114258}}}
#
# #metrics {"StartTime": 1620501117.0047095, "EndTime": 1620501117.0047264, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 17}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2879250955581665, "count": 1, "min": 0.2879250955581665, "max": 0.2879250955581665}}}
#
# #metrics {"StartTime": 1620501117.0047808, "EndTime": 1620501117.0047984, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 18}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.29029906558990476, "count": 1, "min": 0.29029906558990476, "max": 0.29029906558990476}}}
#
# #metrics {"StartTime": 1620501117.0048537, "EndTime": 1620501117.00487, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 19}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.29066307258605956, "count": 1, "min": 0.29066307258605956, "max": 0.29066307258605956}}}
#
# #metrics {"StartTime": 1620501117.0049157, "EndTime": 1620501117.004931, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 20}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.602764814376831, "count": 1, "min": 0.602764814376831, "max": 0.602764814376831}}}
#
# #metrics {"StartTime": 1620501117.0049803, "EndTime": 1620501117.0049958, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 21}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.6040646743774414, "count": 1, "min": 0.6040646743774414, "max": 0.6040646743774414}}}
#
# #metrics {"StartTime": 1620501117.0050519, "EndTime": 1620501117.005068, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 22}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.39841981315612796, "count": 1, "min": 0.39841981315612796, "max": 0.39841981315612796}}}
#
# #metrics {"StartTime": 1620501117.0051107, "EndTime": 1620501117.0051262, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 23}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.6094600410461426, "count": 1, "min": 0.6094600410461426, "max": 0.6094600410461426}}}
#
# #metrics {"StartTime": 1620501117.005168, "EndTime": 1620501117.0051835, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 24}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.28562517547607424, "count": 1, "min": 0.28562517547607424, "max": 0.28562517547607424}}}
#
# #metrics {"StartTime": 1620501117.005235, "EndTime": 1620501117.0052516, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 25}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.28793590641021727, "count": 1, "min": 0.28793590641021727, "max": 0.28793590641021727}}}
#
# #metrics {"StartTime": 1620501117.0052984, "EndTime": 1620501117.0053136, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 26}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.29230369186401367, "count": 1, "min": 0.29230369186401367, "max": 0.29230369186401367}}}
#
# #metrics {"StartTime": 1620501117.0053592, "EndTime": 1620501117.0053747, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 27}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.29264280223846434, "count": 1, "min": 0.29264280223846434, "max": 0.29264280223846434}}}
#
# #metrics {"StartTime": 1620501117.0054178, "EndTime": 1620501117.0054328, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 28}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.5899229564666748, "count": 1, "min": 0.5899229564666748, "max": 0.5899229564666748}}}
#
# #metrics {"StartTime": 1620501117.0054848, "EndTime": 1620501117.0055013, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 29}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.5929205989837647, "count": 1, "min": 0.5929205989837647, "max": 0.5929205989837647}}}
#
# #metrics {"StartTime": 1620501117.0055385, "EndTime": 1620501117.0055535, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 30}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.40020423316955567, "count": 1, "min": 0.40020423316955567, "max": 0.40020423316955567}}}
#
# #metrics {"StartTime": 1620501117.0055957, "EndTime": 1620501117.00561, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 31}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.6571039161682128, "count": 1, "min": 0.6571039161682128, "max": 0.6571039161682128}}}
#
# [05/08/2021 19:11:57 INFO 139703712118592] #quality_metric: host=algo-1, epoch=1, train absolute_loss_objective <loss>=0.2897264394760132
# [05/08/2021 19:11:57 INFO 139703712118592] #early_stopping_criteria_metric: host=algo-1, epoch=1, criteria=absolute_loss_objective, value=0.2812215042114258
# [05/08/2021 19:11:57 INFO 139703712118592] Epoch 1: Loss improved. Updating best model
# [05/08/2021 19:11:57 INFO 139703712118592] Saving model for epoch: 1
# [05/08/2021 19:11:57 INFO 139703712118592] Saved checkpoint to "/tmp/tmppl9t9_q2/mx-mod-0000.params"
# [05/08/2021 19:11:57 INFO 139703712118592] #progress_metric: host=algo-1, completed 20.0 % of epochs
# #metrics {"StartTime": 1620501116.7236402, "EndTime": 1620501117.020709, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 3265.0, "count": 1, "min": 3265, "max": 3265}, "Total Batches Seen": {"sum": 34.0, "count": 1, "min": 34, "max": 34}, "Max Records Seen Between Resets": {"sum": 1055.0, "count": 1, "min": 1055, "max": 1055}, "Max Batches Seen Between Resets": {"sum": 11.0, "count": 1, "min": 11, "max": 11}, "Reset Count": {"sum": 4.0, "count": 1, "min": 4, "max": 4}, "Number of Records Since Last Reset": {"sum": 1055.0, "count": 1, "min": 1055, "max": 1055}, "Number of Batches Since Last Reset": {"sum": 11.0, "count": 1, "min": 11, "max": 11}}}
#
# [05/08/2021 19:11:57 INFO 139703712118592] #throughput_metric: host=algo-1, train throughput=3549.374282102453 records/second
# [2021-05-08 19:11:57.313] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 8, "duration": 292, "num_examples": 11, "num_bytes": 50640}
# #metrics {"StartTime": 1620501117.314307, "EndTime": 1620501117.314452, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 0}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.27059504413604735, "count": 1, "min": 0.27059504413604735, "max": 0.27059504413604735}}}
#
# #metrics {"StartTime": 1620501117.314857, "EndTime": 1620501117.314891, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 1}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.27445756244659425, "count": 1, "min": 0.27445756244659425, "max": 0.27445756244659425}}}
#
# #metrics {"StartTime": 1620501117.3152347, "EndTime": 1620501117.3152642, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 2}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2712486867904663, "count": 1, "min": 0.2712486867904663, "max": 0.2712486867904663}}}
#
# #metrics {"StartTime": 1620501117.315598, "EndTime": 1620501117.3156273, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 3}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2734780101776123, "count": 1, "min": 0.2734780101776123, "max": 0.2734780101776123}}}
#
# #metrics {"StartTime": 1620501117.3159697, "EndTime": 1620501117.3159986, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 4}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3983818607330322, "count": 1, "min": 0.3983818607330322, "max": 0.3983818607330322}}}
#
# #metrics {"StartTime": 1620501117.3163962, "EndTime": 1620501117.316426, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 5}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.31935050010681154, "count": 1, "min": 0.31935050010681154, "max": 0.31935050010681154}}}
#
# #metrics {"StartTime": 1620501117.3167655, "EndTime": 1620501117.316794, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 6}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3060644130706787, "count": 1, "min": 0.3060644130706787, "max": 0.3060644130706787}}}
#
# #metrics {"StartTime": 1620501117.317129, "EndTime": 1620501117.3171577, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 7}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.38661358070373536, "count": 1, "min": 0.38661358070373536, "max": 0.38661358070373536}}}
#
# #metrics {"StartTime": 1620501117.3174808, "EndTime": 1620501117.3175075, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 8}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2753146190643311, "count": 1, "min": 0.2753146190643311, "max": 0.2753146190643311}}}
#
# #metrics {"StartTime": 1620501117.3178291, "EndTime": 1620501117.3178577, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 9}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.27469774436950684, "count": 1, "min": 0.27469774436950684, "max": 0.27469774436950684}}}
#
# #metrics {"StartTime": 1620501117.318172, "EndTime": 1620501117.3182003, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 10}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.27460208892822263, "count": 1, "min": 0.27460208892822263, "max": 0.27460208892822263}}}
#
# #metrics {"StartTime": 1620501117.3185375, "EndTime": 1620501117.3185604, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 11}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2696754112243652, "count": 1, "min": 0.2696754112243652, "max": 0.2696754112243652}}}
#
# #metrics {"StartTime": 1620501117.3188312, "EndTime": 1620501117.3188589, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 12}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.29926835632324217, "count": 1, "min": 0.29926835632324217, "max": 0.29926835632324217}}}
#
# #metrics {"StartTime": 1620501117.3191817, "EndTime": 1620501117.3192105, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 13}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.4050085868835449, "count": 1, "min": 0.4050085868835449, "max": 0.4050085868835449}}}
#
# #metrics {"StartTime": 1620501117.3195324, "EndTime": 1620501117.3195586, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 14}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3438662281036377, "count": 1, "min": 0.3438662281036377, "max": 0.3438662281036377}}}
#
# #metrics {"StartTime": 1620501117.3198783, "EndTime": 1620501117.319905, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 15}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.4020475673675537, "count": 1, "min": 0.4020475673675537, "max": 0.4020475673675537}}}
#
# #metrics {"StartTime": 1620501117.3202271, "EndTime": 1620501117.3202538, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 16}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.27161020755767823, "count": 1, "min": 0.27161020755767823, "max": 0.27161020755767823}}}
#
# #metrics {"StartTime": 1620501117.3205655, "EndTime": 1620501117.3205905, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 17}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.27296836757659915, "count": 1, "min": 0.27296836757659915, "max": 0.27296836757659915}}}
#
# #metrics {"StartTime": 1620501117.320866, "EndTime": 1620501117.3208919, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 18}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2719536542892456, "count": 1, "min": 0.2719536542892456, "max": 0.2719536542892456}}}
#
# #metrics {"StartTime": 1620501117.3211758, "EndTime": 1620501117.3212016, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 19}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2719054555892944, "count": 1, "min": 0.2719054555892944, "max": 0.2719054555892944}}}
#
# #metrics {"StartTime": 1620501117.3214986, "EndTime": 1620501117.3215253, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 20}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.42780605125427246, "count": 1, "min": 0.42780605125427246, "max": 0.42780605125427246}}}
#
# #metrics {"StartTime": 1620501117.3218207, "EndTime": 1620501117.3218472, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 21}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.431686222076416, "count": 1, "min": 0.431686222076416, "max": 0.431686222076416}}}
#
# #metrics {"StartTime": 1620501117.32215, "EndTime": 1620501117.3221765, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 22}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3154920673370361, "count": 1, "min": 0.3154920673370361, "max": 0.3154920673370361}}}
#
# #metrics {"StartTime": 1620501117.3224995, "EndTime": 1620501117.3225195, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 23}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.37741235733032225, "count": 1, "min": 0.37741235733032225, "max": 0.37741235733032225}}}
#
# #metrics {"StartTime": 1620501117.322579, "EndTime": 1620501117.3225958, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 24}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2722831878662109, "count": 1, "min": 0.2722831878662109, "max": 0.2722831878662109}}}
#
# #metrics {"StartTime": 1620501117.3228214, "EndTime": 1620501117.3228471, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 25}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2726433248519897, "count": 1, "min": 0.2726433248519897, "max": 0.2726433248519897}}}
#
# #metrics {"StartTime": 1620501117.323123, "EndTime": 1620501117.323148, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 26}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2713569402694702, "count": 1, "min": 0.2713569402694702, "max": 0.2713569402694702}}}
#
# #metrics {"StartTime": 1620501117.323581, "EndTime": 1620501117.3236482, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 27}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.27129015445709226, "count": 1, "min": 0.27129015445709226, "max": 0.27129015445709226}}}
#
# #metrics {"StartTime": 1620501117.3239563, "EndTime": 1620501117.323982, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 28}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.4323065299987793, "count": 1, "min": 0.4323065299987793, "max": 0.4323065299987793}}}
#
# #metrics {"StartTime": 1620501117.3242824, "EndTime": 1620501117.324309, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 29}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.43598768615722655, "count": 1, "min": 0.43598768615722655, "max": 0.43598768615722655}}}
#
# #metrics {"StartTime": 1620501117.3246047, "EndTime": 1620501117.3246312, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 30}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2935702667236328, "count": 1, "min": 0.2935702667236328, "max": 0.2935702667236328}}}
#
# #metrics {"StartTime": 1620501117.3249445, "EndTime": 1620501117.3249707, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "model": 31}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.5451347770690917, "count": 1, "min": 0.5451347770690917, "max": 0.5451347770690917}}}
#
# [05/08/2021 19:11:57 INFO 139703712118592] #quality_metric: host=algo-1, epoch=2, train absolute_loss_objective <loss>=0.27059504413604735
# [05/08/2021 19:11:57 INFO 139703712118592] #early_stopping_criteria_metric: host=algo-1, epoch=2, criteria=absolute_loss_objective, value=0.2696754112243652
# [05/08/2021 19:11:57 INFO 139703712118592] Epoch 2: Loss improved. Updating best model
# [05/08/2021 19:11:57 INFO 139703712118592] Saving model for epoch: 2
# [05/08/2021 19:11:57 INFO 139703712118592] Saved checkpoint to "/tmp/tmp4k8ghely/mx-mod-0000.params"
# [05/08/2021 19:11:57 INFO 139703712118592] #progress_metric: host=algo-1, completed 30.0 % of epochs
# #metrics {"StartTime": 1620501117.021058, "EndTime": 1620501117.3667939, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 2, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 4320.0, "count": 1, "min": 4320, "max": 4320}, "Total Batches Seen": {"sum": 45.0, "count": 1, "min": 45, "max": 45}, "Max Records Seen Between Resets": {"sum": 1055.0, "count": 1, "min": 1055, "max": 1055}, "Max Batches Seen Between Resets": {"sum": 11.0, "count": 1, "min": 11, "max": 11}, "Reset Count": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Number of Records Since Last Reset": {"sum": 1055.0, "count": 1, "min": 1055, "max": 1055}, "Number of Batches Since Last Reset": {"sum": 11.0, "count": 1, "min": 11, "max": 11}}}
#
# [05/08/2021 19:11:57 INFO 139703712118592] #throughput_metric: host=algo-1, train throughput=3049.938256713669 records/second
# [2021-05-08 19:11:57.625] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 10, "duration": 257, "num_examples": 11, "num_bytes": 50640}
# #metrics {"StartTime": 1620501117.62516, "EndTime": 1620501117.6252544, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 0}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.26656030654907226, "count": 1, "min": 0.26656030654907226, "max": 0.26656030654907226}}}
#
# #metrics {"StartTime": 1620501117.6253936, "EndTime": 1620501117.6254241, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 1}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.26832919120788573, "count": 1, "min": 0.26832919120788573, "max": 0.26832919120788573}}}
#
# #metrics {"StartTime": 1620501117.6254947, "EndTime": 1620501117.6255143, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 2}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.26774904346466066, "count": 1, "min": 0.26774904346466066, "max": 0.26774904346466066}}}
#
# #metrics {"StartTime": 1620501117.6255846, "EndTime": 1620501117.6256037, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 3}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2667884168624878, "count": 1, "min": 0.2667884168624878, "max": 0.2667884168624878}}}
#
# #metrics {"StartTime": 1620501117.6256635, "EndTime": 1620501117.625681, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 4}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3282097110748291, "count": 1, "min": 0.3282097110748291, "max": 0.3282097110748291}}}
#
# #metrics {"StartTime": 1620501117.625739, "EndTime": 1620501117.6257572, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 5}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2920069341659546, "count": 1, "min": 0.2920069341659546, "max": 0.2920069341659546}}}
#
# #metrics {"StartTime": 1620501117.625814, "EndTime": 1620501117.625831, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 6}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.32793076705932617, "count": 1, "min": 0.32793076705932617, "max": 0.32793076705932617}}}
#
# #metrics {"StartTime": 1620501117.625887, "EndTime": 1620501117.6259034, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 7}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3471343870162964, "count": 1, "min": 0.3471343870162964, "max": 0.3471343870162964}}}
#
# #metrics {"StartTime": 1620501117.6259594, "EndTime": 1620501117.6259768, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 8}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.26800649738311766, "count": 1, "min": 0.26800649738311766, "max": 0.26800649738311766}}}
#
# #metrics {"StartTime": 1620501117.6260312, "EndTime": 1620501117.6260486, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 9}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.27189188861846925, "count": 1, "min": 0.27189188861846925, "max": 0.27189188861846925}}}
#
# #metrics {"StartTime": 1620501117.6261017, "EndTime": 1620501117.6261187, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 10}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.27055471897125244, "count": 1, "min": 0.27055471897125244, "max": 0.27055471897125244}}}
#
# #metrics {"StartTime": 1620501117.6261733, "EndTime": 1620501117.6261911, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 11}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.26449027729034424, "count": 1, "min": 0.26449027729034424, "max": 0.26449027729034424}}}
#
# #metrics {"StartTime": 1620501117.6262467, "EndTime": 1620501117.6262877, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 12}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3019922332763672, "count": 1, "min": 0.3019922332763672, "max": 0.3019922332763672}}}
#
# #metrics {"StartTime": 1620501117.626347, "EndTime": 1620501117.626365, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 13}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3899210910797119, "count": 1, "min": 0.3899210910797119, "max": 0.3899210910797119}}}
#
# #metrics {"StartTime": 1620501117.6264198, "EndTime": 1620501117.6264367, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 3, "model": 14}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3388494243621826, "count": 1, "min": 0.3388494243621826, "max": 0.3388494243621826}}}
#
# ...
#
# #metrics {"StartTime": 1620501119.0507746, "EndTime": 1620501119.0507863, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 2}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2636075973510742, "count": 1, "min": 0.2636075973510742, "max": 0.2636075973510742}}}
#
# #metrics {"StartTime": 1620501119.050828, "EndTime": 1620501119.050839, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 3}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.26368825912475585, "count": 1, "min": 0.26368825912475585, "max": 0.26368825912475585}}}
#
# #metrics {"StartTime": 1620501119.05088, "EndTime": 1620501119.0508907, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 4}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3274765281677246, "count": 1, "min": 0.3274765281677246, "max": 0.3274765281677246}}}
#
# #metrics {"StartTime": 1620501119.0509307, "EndTime": 1620501119.0509412, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 5}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.31695183181762693, "count": 1, "min": 0.31695183181762693, "max": 0.31695183181762693}}}
#
# #metrics {"StartTime": 1620501119.0509808, "EndTime": 1620501119.0509913, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 6}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.31526430130004884, "count": 1, "min": 0.31526430130004884, "max": 0.31526430130004884}}}
#
# #metrics {"StartTime": 1620501119.0510309, "EndTime": 1620501119.0510416, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 7}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2830472354888916, "count": 1, "min": 0.2830472354888916, "max": 0.2830472354888916}}}
#
# #metrics {"StartTime": 1620501119.0510807, "EndTime": 1620501119.0510912, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 8}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.26273527431488036, "count": 1, "min": 0.26273527431488036, "max": 0.26273527431488036}}}
#
# #metrics {"StartTime": 1620501119.0511305, "EndTime": 1620501119.051141, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 9}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2639871425628662, "count": 1, "min": 0.2639871425628662, "max": 0.2639871425628662}}}
#
# #metrics {"StartTime": 1620501119.0511804, "EndTime": 1620501119.0511909, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 10}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.26263426113128663, "count": 1, "min": 0.26263426113128663, "max": 0.26263426113128663}}}
#
# #metrics {"StartTime": 1620501119.051231, "EndTime": 1620501119.0512414, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 11}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.26281993198394776, "count": 1, "min": 0.26281993198394776, "max": 0.26281993198394776}}}
#
# #metrics {"StartTime": 1620501119.051281, "EndTime": 1620501119.0512917, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 12}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.31957221603393554, "count": 1, "min": 0.31957221603393554, "max": 0.31957221603393554}}}
#
# #metrics {"StartTime": 1620501119.0513308, "EndTime": 1620501119.0513415, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 13}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.34399952507019044, "count": 1, "min": 0.34399952507019044, "max": 0.34399952507019044}}}
#
# #metrics {"StartTime": 1620501119.0513804, "EndTime": 1620501119.0513911, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 14}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2946230297088623, "count": 1, "min": 0.2946230297088623, "max": 0.2946230297088623}}}
#
# #metrics {"StartTime": 1620501119.0514302, "EndTime": 1620501119.0514407, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 15}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3614532241821289, "count": 1, "min": 0.3614532241821289, "max": 0.3614532241821289}}}
#
# #metrics {"StartTime": 1620501119.0514798, "EndTime": 1620501119.0514903, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 16}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.26361176109313966, "count": 1, "min": 0.26361176109313966, "max": 0.26361176109313966}}}
#
# #metrics {"StartTime": 1620501119.0515294, "EndTime": 1620501119.05154, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 17}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2642582311630249, "count": 1, "min": 0.2642582311630249, "max": 0.2642582311630249}}}
#
# #metrics {"StartTime": 1620501119.051579, "EndTime": 1620501119.051589, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 18}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.26397590827941897, "count": 1, "min": 0.26397590827941897, "max": 0.26397590827941897}}}
#
# #metrics {"StartTime": 1620501119.0516284, "EndTime": 1620501119.051642, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 19}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2634526557922363, "count": 1, "min": 0.2634526557922363, "max": 0.2634526557922363}}}
#
# #metrics {"StartTime": 1620501119.051682, "EndTime": 1620501119.051693, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 20}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.31049581527709963, "count": 1, "min": 0.31049581527709963, "max": 0.31049581527709963}}}
#
# #metrics {"StartTime": 1620501119.0517328, "EndTime": 1620501119.0517435, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 21}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.33159138107299807, "count": 1, "min": 0.33159138107299807, "max": 0.33159138107299807}}}
#
# #metrics {"StartTime": 1620501119.0517857, "EndTime": 1620501119.0517967, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 22}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.30838071060180666, "count": 1, "min": 0.30838071060180666, "max": 0.30838071060180666}}}
#
# #metrics {"StartTime": 1620501119.0518363, "EndTime": 1620501119.0518467, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 23}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3587107419967651, "count": 1, "min": 0.3587107419967651, "max": 0.3587107419967651}}}
#
# #metrics {"StartTime": 1620501119.0518856, "EndTime": 1620501119.0518959, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 24}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.26812195205688477, "count": 1, "min": 0.26812195205688477, "max": 0.26812195205688477}}}
#
# #metrics {"StartTime": 1620501119.0519347, "EndTime": 1620501119.0519452, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 25}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.26702385330200196, "count": 1, "min": 0.26702385330200196, "max": 0.26702385330200196}}}
#
# #metrics {"StartTime": 1620501119.0519848, "EndTime": 1620501119.051995, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 26}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.26473277950286866, "count": 1, "min": 0.26473277950286866, "max": 0.26473277950286866}}}
#
# #metrics {"StartTime": 1620501119.0520349, "EndTime": 1620501119.0520456, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 27}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.2643996419906616, "count": 1, "min": 0.2643996419906616, "max": 0.2643996419906616}}}
#
# #metrics {"StartTime": 1620501119.0520847, "EndTime": 1620501119.0520952, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 28}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.41221200942993164, "count": 1, "min": 0.41221200942993164, "max": 0.41221200942993164}}}
#
# #metrics {"StartTime": 1620501119.0521388, "EndTime": 1620501119.0521483, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 29}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.36444423866271974, "count": 1, "min": 0.36444423866271974, "max": 0.36444423866271974}}}
#
# #metrics {"StartTime": 1620501119.052177, "EndTime": 1620501119.0521848, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 30}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.3598373489379883, "count": 1, "min": 0.3598373489379883, "max": 0.3598373489379883}}}
#
# #metrics {"StartTime": 1620501119.0522115, "EndTime": 1620501119.0522192, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "model": 31}, "Metrics": {"train_absolute_loss_objective": {"sum": 0.30116380882263183, "count": 1, "min": 0.30116380882263183, "max": 0.30116380882263183}}}
#
# [05/08/2021 19:11:59 INFO 139703712118592] #quality_metric: host=algo-1, epoch=8, train absolute_loss_objective <loss>=0.2643521385192871
# [05/08/2021 19:11:59 INFO 139703712118592] #early_stopping_criteria_metric: host=algo-1, epoch=8, criteria=absolute_loss_objective, value=0.26263426113128663
# [05/08/2021 19:11:59 INFO 139703712118592] Saving model for epoch: 8
# [05/08/2021 19:11:59 INFO 139703712118592] Saved checkpoint to "/tmp/tmpzv1by4r1/mx-mod-0000.params"
# [05/08/2021 19:11:59 INFO 139703712118592] Early stop condition met. Stopping training.
# [05/08/2021 19:11:59 INFO 139703712118592] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"StartTime": 1620501118.7885048, "EndTime": 1620501119.0640595, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 8, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 10650.0, "count": 1, "min": 10650, "max": 10650}, "Total Batches Seen": {"sum": 111.0, "count": 1, "min": 111, "max": 111}, "Max Records Seen Between Resets": {"sum": 1055.0, "count": 1, "min": 1055, "max": 1055}, "Max Batches Seen Between Resets": {"sum": 11.0, "count": 1, "min": 11, "max": 11}, "Reset Count": {"sum": 11.0, "count": 1, "min": 11, "max": 11}, "Number of Records Since Last Reset": {"sum": 1055.0, "count": 1, "min": 1055, "max": 1055}, "Number of Batches Since Last Reset": {"sum": 11.0, "count": 1, "min": 11, "max": 11}}}
#
# [05/08/2021 19:11:59 INFO 139703712118592] #throughput_metric: host=algo-1, train throughput=3826.1453990180835 records/second
# [05/08/2021 19:11:59 WARNING 139703712118592] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [05/08/2021 19:11:59 WARNING 139703712118592] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [2021-05-08 19:11:59.065] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 22, "duration": 0, "num_examples": 1, "num_bytes": 4800}
# [2021-05-08 19:11:59.103] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 24, "duration": 18, "num_examples": 11, "num_bytes": 50640}
# [05/08/2021 19:11:59 INFO 139703712118592] #train_score (algo-1) : ('absolute_loss_objective', 0.11295952277160934)
# [05/08/2021 19:11:59 INFO 139703712118592] #train_score (algo-1) : ('mse', 0.1907624240170158)
# [05/08/2021 19:11:59 INFO 139703712118592] #train_score (algo-1) : ('absolute_loss', 0.11295952277160934)
# [05/08/2021 19:11:59 INFO 139703712118592] #quality_metric: host=algo-1, train absolute_loss_objective <loss>=0.11295952277160934
# [05/08/2021 19:11:59 INFO 139703712118592] #quality_metric: host=algo-1, train mse <loss>=0.1907624240170158
# [05/08/2021 19:11:59 INFO 139703712118592] #quality_metric: host=algo-1, train absolute_loss <loss>=0.11295952277160934
# [05/08/2021 19:11:59 INFO 139703712118592] Best model found for hyperparameters: {"optimizer": "adam", "learning_rate": 0.005, "wd": 100, "l1": 0.0, "lr_scheduler_step": 10, "lr_scheduler_factor": 0.99, "lr_scheduler_minimum_lr": 0.0001}
# [05/08/2021 19:11:59 INFO 139703712118592] Saved checkpoint to "/tmp/tmpir_qz9e8/mx-mod-0000.params"
# [2021-05-08 19:11:59.107] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/test", "epoch": 0, "duration": 2891, "num_examples": 1, "num_bytes": 4800}
# [2021-05-08 19:11:59.118] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/test", "epoch": 1, "duration": 11, "num_examples": 3, "num_bytes": 12672}
# #metrics {"StartTime": 1620501119.107417, "EndTime": 1620501119.1190963, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "Meta": "test_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 264.0, "count": 1, "min": 264, "max": 264}, "Total Batches Seen": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Max Records Seen Between Resets": {"sum": 264.0, "count": 1, "min": 264, "max": 264}, "Max Batches Seen Between Resets": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Reset Count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Number of Records Since Last Reset": {"sum": 264.0, "count": 1, "min": 264, "max": 264}, "Number of Batches Since Last Reset": {"sum": 3.0, "count": 1, "min": 3, "max": 3}}}
#
# [05/08/2021 19:11:59 INFO 139703712118592] #test_score (algo-1) : ('absolute_loss_objective', 0.12122747753605698)
# [05/08/2021 19:11:59 INFO 139703712118592] #test_score (algo-1) : ('mse', 0.21777615041443796)
# [05/08/2021 19:11:59 INFO 139703712118592] #test_score (algo-1) : ('absolute_loss', 0.12122747753605698)
# [05/08/2021 19:11:59 INFO 139703712118592] #quality_metric: host=algo-1, test absolute_loss_objective <loss>=0.12122747753605698
# [05/08/2021 19:11:59 INFO 139703712118592] #quality_metric: host=algo-1, test mse <loss>=0.21777615041443796
# [05/08/2021 19:11:59 INFO 139703712118592] #quality_metric: host=algo-1, test absolute_loss <loss>=0.12122747753605698
# #metrics {"StartTime": 1620501116.2151268, "EndTime": 1620501119.1242619, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 228.4083366394043, "count": 1, "min": 228.4083366394043, "max": 228.4083366394043}, "epochs": {"sum": 10.0, "count": 1, "min": 10, "max": 10}, "check_early_stopping.time": {"sum": 9.468317031860352, "count": 9, "min": 0.20551681518554688, "max": 2.682924270629883}, "update.time": {"sum": 2555.711030960083, "count": 9, "min": 257.82179832458496, "max": 326.1687755584717}, "finalize.time": {"sum": 39.8709774017334, "count": 1, "min": 39.8709774017334, "max": 39.8709774017334}, "setuptime": {"sum": 33.74791145324707, "count": 1, "min": 33.74791145324707, "max": 33.74791145324707}, "totaltime": {"sum": 3214.4815921783447, "count": 1, "min": 3214.4815921783447, "max": 3214.4815921783447}}}
#
#
# 2021-05-08 19:12:11 Uploading - Uploading generated training model
# 2021-05-08 19:12:11 Completed - Training job completed
# Training seconds: 65
# Billable seconds: 65

# %% [markdown]
# ## Deploying the Model to Make Predictions

# %%
# An instance of the linear-learner predictor is created
linear_predictor = linear.deploy(initial_instance_count=1, instance_type="ml.t2.medium")
# Out:
# -----------------!

# %%
# Linear predictor configurations
linear_predictor.serializer = csv_serializer
linear_predictor.deserializer = json_deserializer

# %%
# Making some predictions using the test data.
result = linear_predictor.predict(X_test)
y_predictions = np.array([r["score"] for r in result["predictions"]])
y_predictions[:5]
# Out:
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# array([0.00036862, 0.00033051, 0.00065443, 0.00033051, 0.00036862])

# %% [markdown]
# ### Model Evaluation

# %%
# Plotting predicted Vs. actual values
plt.plot(np.array(y_test), label="actual")
plt.plot(y_predictions, label="predict")
plt.legend()
plt.show()

# %%
# Calculating the RMSE and R2 scores
rmse = np.sqrt(mean_squared_error(y_test, y_predictions))
r2 = r2_score(y_test, y_predictions)

print("RMSE: {}".format(rmse))
print("R2 score: {}".format(r2))
# Out:
# RMSE: 0.46666492175760504
# R2 score: -0.07147687968171734

# %% [markdown]
# ### Delete Amazon SageMaker end-point

# %%
sagemaker.Session().delete_endpoint(linear_predictor.endpoint)
# Out:
# The endpoint attribute has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
