# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import statsmodels as sm
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
from pathlib import Path
csvpath = Path('Resources/weather.csv', parse_dates=True, index_col='Date')
df = pd.read_csv(csvpath)
# Temperature readings of the first 24 hours
df.Temperature[:24]
# Out:
# 0     46.2
# 1     44.6
# 2     44.1
# 3     43.8
# 4     43.5
# 5     43.0
# 6     43.1
# 7     42.3
# 8     42.5
# 9     45.9
# 10    49.4
# 11    52.4
# 12    54.9
# 13    57.1
# 14    58.4
# 15    59.1
# 16    59.1
# 17    58.0
# 18    54.5
# 19    51.3
# 20    49.2
# 21    48.1
# 22    47.2
# 23    46.4
# Name: Temperature, dtype: float64

# %%
df.Temperature.plot()
# Out:
# <AxesSubplot:>

# %%
df.Temperature[:24].plot()
# Out:
# <AxesSubplot:>

# %%
df.Temperature[:72].plot()
# Out:
# <AxesSubplot:>

# %%
df.head()
# Out:
#    Temperature  DewPoint  Pressure            Date
# 0         46.2      37.5       1.0  20100101 00:00
# 1         44.6      37.1       1.0  20100101 01:00
# 2         44.1      36.9       1.0  20100101 02:00
# 3         43.8      36.9       1.0  20100101 03:00
# 4         43.5      36.8       1.0  20100101 04:00

# %%
df['Lag_Temperature'] = df.Temperature.shift()
df['Temperature_Difference'] = df.Temperature.diff()

# %%
df.head()
# Out:
#    Temperature  DewPoint  Pressure            Date  Lag_Temperature  \
# 0         46.2      37.5       1.0  20100101 00:00              NaN
# 1         44.6      37.1       1.0  20100101 01:00             46.2
# 2         44.1      36.9       1.0  20100101 02:00             44.6
# 3         43.8      36.9       1.0  20100101 03:00             44.1
# 4         43.5      36.8       1.0  20100101 04:00             43.8
#
#    Temperature_Difference
# 0                     NaN
# 1                    -1.6
# 2                    -0.5
# 3                    -0.3
# 4                    -0.3

# %%
plt.scatter(df['Lag_Temperature'], df['Temperature'])

# %%
df.Temperature.autocorr(lag=1)
# Out:
# 0.9909018726597646

# %%
df.Temperature.autocorr(lag=12)
# Out:
# 0.5922790791488816

# %%
df.Temperature.autocorr(lag=24)
# Out:
# 0.9997947452312896

# %%
plot_acf(df.Temperature, lags=48)

# %%
plot_pacf(df.Temperature, lags=26, zero=False)
