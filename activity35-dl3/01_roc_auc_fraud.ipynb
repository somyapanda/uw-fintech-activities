# %% [markdown]
# # Instructor Do: Intro to the ROC Curve and AUC
#
# In this activity, students will learn how to measure the performance of a binary classification model by fetching metrics from Keras, as well as plotting and interpreting the ROC curve and AUC.

# %%
# Initial imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from pathlib import Path

# %matplotlib inline

# %% [markdown]
# ## The Dataset
#
# The data provided for this demo contains anonymous information about `284807` credit card transactions made by European credit cardholders in September 2013.
#
# The dataset is going to be used to create a binary classification model using a deep neural network to detect fraudulent transactions. It contains nine numerical variables, which are the result of PCA transformation to protect the confidentiality of credit cardholders. Only the transaction amount can be seen as is.
#
# This dataset is an abstract of the file shared by the [Machine Learning Group](http://mlg.ulb.ac.be) of the Université Libre de Bruxelles (ULB).

# %%
# Import the dataset
transaction_df = pd.read_csv("transactions.csv")
transaction_df.head()
# Out:
#          V1        V2        V3        V4  ...        V8        V9  Amount  Class
# 0 -1.359807 -0.072781  2.536347  1.378155  ...  0.098698  0.363787  149.62      0
# 1  1.191857  0.266151  0.166480  0.448154  ...  0.085102 -0.255425    2.69      0
# 2 -1.358354 -1.340163  1.773209  0.379780  ...  0.247676 -1.514654  378.66      0
# 3 -0.966272 -0.185226  1.792993 -0.863291  ...  0.377436 -1.387024  123.50      0
# 4 -1.158233  0.877737  1.548718  0.403034  ... -0.270533  0.817739   69.99      0
#
# [5 rows x 11 columns]

# %% [markdown]
# ## Data Preprocessing

# %%
# Creating the X and y sets
X = transaction_df.iloc[:, 0:10].values
y = transaction_df['Class'].values

# %%
# Import the StandardScaler from sklearn
from sklearn.preprocessing import StandardScaler

# Scale the data
scaler = StandardScaler().fit(X)
X = scaler.transform(X)

# %% [markdown]
# Now that the data is scaled, the training, validation, and testing sets will be created.

# %%
# Creating training, validation, and testing sets
from sklearn.model_selection import train_test_split

X_bulk, X_test, y_bulk, y_test = train_test_split(X, y, random_state=78)
X_train, X_val, y_train, y_val = train_test_split(X_bulk, y_bulk, random_state=78)

# %% [markdown]
# ## Build and Train the Deep Learning Model

# %% [markdown]
#  ### Importing the Keras Modules

# %%
# Import Keras modules for model creation
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
#  ### Setting Up the Model

# %%
# Model set-up
number_input_features = 10
hidden_nodes_layer1 = 15
hidden_nodes_layer2 = 5

# %% [markdown]
#  ### Defining the Model's Structure

# %%
# Define the LSTM RNN model
model = Sequential()
# Layer 1
model.add(Dense(
    units=hidden_nodes_layer1,
    input_dim=number_input_features,
    activation='relu'
))

# Layer 2
model.add(Dense(
    units=hidden_nodes_layer2, activation='relu'
))
# Output layer
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
#  ### Compiling the Model

# %%
# Compile the model
model.compile(
    loss='binary_crossentropy',
    optimizer='adam',
    metrics=[
        tf.keras.metrics.TruePositives(name="tp"),
        tf.keras.metrics.TrueNegatives(name="tn"),
        tf.keras.metrics.FalsePositives(name="fp"),
        tf.keras.metrics.FalseNegatives(name="fn"),
        tf.keras.metrics.Precision(name="precision"),
        tf.keras.metrics.Recall(name="recall"),
        tf.keras.metrics.AUC(name="auc"),
    ]
)

# %%
# Summarize the model
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 15)                165
# _________________________________________________________________
# dense_6 (Dense)              (None, 5)                 80
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 6
# =================================================================
# Total params: 251
# Trainable params: 251
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
#  ### Training the Model

# %%
# Training the model
batch_size = 1000
epochs = 50
training_history = model.fit(
    X_train,
    y_train,
    validation_data=(X_val, y_val),
    epochs=epochs,
    batch_size=batch_size,
    verbose=1,
)
# Out:
# Epoch 1/50
# 161/161 [==============================] - 4s 12ms/step - loss: 0.7952 - tp: 108.6852 - tn: 43672.3086 - fp: 37681.6975 - fn: 21.2963 - precision: 0.0027 - recall: 0.8714 - auc: 0.8456 - val_loss: 0.3052 - val_tp: 23.0000 - val_tn: 53193.0000 - val_fp: 104.0000 - val_fn: 82.0000 - val_precision: 0.1811 - val_recall: 0.2190 - val_auc: 0.7157
# Epoch 2/50
# 161/161 [==============================] - 1s 6ms/step - loss: 0.2174 - tp: 7.8210 - tn: 81309.1420 - fp: 43.7160 - fn: 123.3086 - precision: 0.1394 - recall: 0.0626 - auc: 0.5852 - val_loss: 0.0648 - val_tp: 4.0000 - val_tn: 53297.0000 - val_fp: 0.0000e+00 - val_fn: 101.0000 - val_precision: 1.0000 - val_recall: 0.0381 - val_auc: 0.5501
# Epoch 3/50
# 161/161 [==============================] - 1s 7ms/step - loss: 0.0482 - tp: 9.1296 - tn: 81350.9198 - fp: 1.6420 - fn: 122.2963 - precision: 0.8604 - recall: 0.0639 - auc: 0.6633 - val_loss: 0.0243 - val_tp: 12.0000 - val_tn: 53296.0000 - val_fp: 1.0000 - val_fn: 93.0000 - val_precision: 0.9231 - val_recall: 0.1143 - val_auc: 0.7791
# Epoch 4/50
# 161/161 [==============================] - 1s 7ms/step - loss: 0.0199 - tp: 17.4259 - tn: 81350.0741 - fp: 4.0000 - fn: 112.4877 - precision: 0.7607 - recall: 0.1057 - auc: 0.7764 - val_loss: 0.0147 - val_tp: 27.0000 - val_tn: 53287.0000 - val_fp: 10.0000 - val_fn: 78.0000 - val_precision: 0.7297 - val_recall: 0.2571 - val_auc: 0.8566
# Epoch 5/50
# 161/161 [==============================] - 1s 7ms/step - loss: 0.0120 - tp: 34.6420 - tn: 81344.4321 - fp: 7.8951 - fn: 97.0185 - precision: 0.7980 - recall: 0.2622 - auc: 0.8805 - val_loss: 0.0110 - val_tp: 30.0000 - val_tn: 53285.0000 - val_fp: 12.0000 - val_fn: 75.0000 - val_precision: 0.7143 - val_recall: 0.2857 - val_auc: 0.8907
# Epoch 6/50
# 161/161 [==============================] - 1s 7ms/step - loss: 0.0096 - tp: 42.6667 - tn: 81344.2716 - fp: 6.9938 - fn: 90.0556 - precision: 0.8619 - recall: 0.3094 - auc: 0.8877 - val_loss: 0.0091 - val_tp: 32.0000 - val_tn: 53284.0000 - val_fp: 13.0000 - val_fn: 73.0000 - val_precision: 0.7111 - val_recall: 0.3048 - val_auc: 0.9033
# Epoch 7/50
# 161/161 [==============================] - 1s 7ms/step - loss: 0.0088 - tp: 47.2963 - tn: 81337.8827 - fp: 9.9815 - fn: 88.8272 - precision: 0.8089 - recall: 0.3287 - auc: 0.8628 - val_loss: 0.0080 - val_tp: 38.0000 - val_tn: 53283.0000 - val_fp: 14.0000 - val_fn: 67.0000 - val_precision: 0.7308 - val_recall: 0.3619 - val_auc: 0.9128
# Epoch 8/50
# 161/161 [==============================] - 1s 7ms/step - loss: 0.0071 - tp: 47.6296 - tn: 81346.4136 - fp: 9.5370 - fn: 80.4074 - precision: 0.8456 - recall: 0.3619 - auc: 0.8900 - val_loss: 0.0073 - val_tp: 45.0000 - val_tn: 53283.0000 - val_fp: 14.0000 - val_fn: 60.0000 - val_precision: 0.7627 - val_recall: 0.4286 - val_auc: 0.9130
# Epoch 9/50
# 161/161 [==============================] - 1s 7ms/step - loss: 0.0059 - tp: 58.0247 - tn: 81345.8580 - fp: 7.6852 - fn: 72.4198 - precision: 0.8986 - recall: 0.4800 - auc: 0.8862 - val_loss: 0.0068 - val_tp: 48.0000 - val_tn: 53283.0000 - val_fp: 14.0000 - val_fn: 57.0000 - val_precision: 0.7742 - val_recall: 0.4571 - val_auc: 0.9060
# Epoch 10/50
# 161/161 [==============================] - 1s 7ms/step - loss: 0.0060 - tp: 48.5309 - tn: 81352.1420 - fp: 10.7840 - fn: 72.5309 - precision: 0.7929 - recall: 0.3532 - auc: 0.8802 - val_loss: 0.0065 - val_tp: 52.0000 - val_tn: 53283.0000 - val_fp: 14.0000 - val_fn: 53.0000 - val_precision: 0.7879 - val_recall: 0.4952 - val_auc: 0.9075
# Epoch 11/50
# 161/161 [==============================] - 1s 7ms/step - loss: 0.0054 - tp: 61.8457 - tn: 81339.1852 - fp: 9.1975 - fn: 73.7593 - precision: 0.8942 - recall: 0.4885 - auc: 0.8962 - val_loss: 0.0061 - val_tp: 54.0000 - val_tn: 53284.0000 - val_fp: 13.0000 - val_fn: 51.0000 - val_precision: 0.8060 - val_recall: 0.5143 - val_auc: 0.9086
# Epoch 12/50
# 161/161 [==============================] - 1s 7ms/step - loss: 0.0053 - tp: 60.4691 - tn: 81346.3765 - fp: 9.4568 - fn: 67.6852 - precision: 0.8683 - recall: 0.4641 - auc: 0.9107 - val_loss: 0.0060 - val_tp: 57.0000 - val_tn: 53283.0000 - val_fp: 14.0000 - val_fn: 48.0000 - val_precision: 0.8028 - val_recall: 0.5429 - val_auc: 0.9141
# Epoch 13/50
# 161/161 [==============================] - 1s 7ms/step - loss: 0.0054 - tp: 68.7407 - tn: 81341.6111 - fp: 8.1173 - fn: 65.5185 - precision: 0.8869 - recall: 0.4674 - auc: 0.8983 - val_loss: 0.0056 - val_tp: 54.0000 - val_tn: 53284.0000 - val_fp: 13.0000 - val_fn: 51.0000 - val_precision: 0.8060 - val_recall: 0.5143 - val_auc: 0.9147
# Epoch 14/50
# 161/161 [==============================] - 1s 7ms/step - loss: 0.0051 - tp: 69.0679 - tn: 81340.1358 - fp: 8.5926 - fn: 66.1914 - precision: 0.9001 - recall: 0.4802 - auc: 0.9076 - val_loss: 0.0055 - val_tp: 57.0000 - val_tn: 53284.0000 - val_fp: 13.0000 - val_fn: 48.0000 - val_precision: 0.8143 - val_recall: 0.5429 - val_auc: 0.9152
# Epoch 15/50
# 161/161 [==============================] - 1s 7ms/step - loss: 0.0046 - tp: 66.8148 - tn: 81344.5741 - fp: 8.0062 - fn: 64.5926 - precision: 0.8916 - recall: 0.5033 - auc: 0.9071 - val_loss: 0.0054 - val_tp: 58.0000 - val_tn: 53284.0000 - val_fp: 13.0000 - val_fn: 47.0000 - val_precision: 0.8169 - val_recall: 0.5524 - val_auc: 0.9155
# Epoch 16/50
# 161/161 [==============================] - 1s 7ms/step - loss: 0.0048 - tp: 72.7160 - tn: 81337.7963 - fp: 8.4136 - fn: 65.0617 - precision: 0.9049 - recall: 0.4963 - auc: 0.8936 - val_loss: 0.0053 - val_tp: 62.0000 - val_tn: 53284.0000 - val_fp: 13.0000 - val_fn: 43.0000 - val_precision: 0.8267 - val_recall: 0.5905 - val_auc: 0.9205
# Epoch 17/50
# 161/161 [==============================] - 1s 7ms/step - loss: 0.0045 - tp: 76.7716 - tn: 81342.3827 - fp: 8.1728 - fn: 56.6605 - precision: 0.9146 - recall: 0.5959 - auc: 0.9058 - val_loss: 0.0051 - val_tp: 61.0000 - val_tn: 53284.0000 - val_fp: 13.0000 - val_fn: 44.0000 - val_precision: 0.8243 - val_recall: 0.5810 - val_auc: 0.9302
# Epoch 18/50
# 161/161 [==============================] - 1s 7ms/step - loss: 0.0052 - tp: 69.1235 - tn: 81342.3704 - fp: 9.1049 - fn: 63.3889 - precision: 0.8566 - recall: 0.4826 - auc: 0.8677 - val_loss: 0.0051 - val_tp: 62.0000 - val_tn: 53284.0000 - val_fp: 13.0000 - val_fn: 43.0000 - val_precision: 0.8267 - val_recall: 0.5905 - val_auc: 0.9257
# Epoch 19/50
# 161/161 [==============================] - 1s 7ms/step - loss: 0.0044 - tp: 73.0988 - tn: 81339.5802 - fp: 10.1790 - fn: 61.1296 - precision: 0.8854 - recall: 0.5576 - auc: 0.9001 - val_loss: 0.0050 - val_tp: 65.0000 - val_tn: 53284.0000 - val_fp: 13.0000 - val_fn: 40.0000 - val_precision: 0.8333 - val_recall: 0.6190 - val_auc: 0.9305
# Epoch 20/50
# 161/161 [==============================] - 1s 7ms/step - loss: 0.0047 - tp: 68.9321 - tn: 81342.6481 - fp: 8.6049 - fn: 63.8025 - precision: 0.8568 - recall: 0.4761 - auc: 0.8808 - val_loss: 0.0049 - val_tp: 64.0000 - val_tn: 53284.0000 - val_fp: 13.0000 - val_fn: 41.0000 - val_precision: 0.8312 - val_recall: 0.6095 - val_auc: 0.9307
# Epoch 21/50
# 161/161 [==============================] - 1s 7ms/step - loss: 0.0039 - tp: 76.8272 - tn: 81342.1914 - fp: 6.4259 - fn: 58.5432 - precision: 0.9409 - recall: 0.5671 - auc: 0.9103 - val_loss: 0.0048 - val_tp: 64.0000 - val_tn: 53284.0000 - val_fp: 13.0000 - val_fn: 41.0000 - val_precision: 0.8312 - val_recall: 0.6095 - val_auc: 0.9308
# Epoch 22/50
# 161/161 [==============================] - 1s 7ms/step - loss: 0.0047 - tp: 72.6790 - tn: 81342.3333 - fp: 8.3148 - fn: 60.6605 - precision: 0.8864 - recall: 0.5297 - auc: 0.8983 - val_loss: 0.0049 - val_tp: 66.0000 - val_tn: 53284.0000 - val_fp: 13.0000 - val_fn: 39.0000 - val_precision: 0.8354 - val_recall: 0.6286 - val_auc: 0.9311
# Epoch 23/50
# 161/161 [==============================] - 1s 7ms/step - loss: 0.0044 - tp: 73.8827 - tn: 81336.7037 - fp: 9.2840 - fn: 64.1173 - precision: 0.8919 - recall: 0.5425 - auc: 0.9159 - val_loss: 0.0047 - val_tp: 64.0000 - val_tn: 53284.0000 - val_fp: 13.0000 - val_fn: 41.0000 - val_precision: 0.8312 - val_recall: 0.6095 - val_auc: 0.9311
# Epoch 24/50
# 161/161 [==============================] - 1s 7ms/step - loss: 0.0032 - tp: 69.9691 - tn: 81352.9506 - fp: 9.0185 - fn: 52.0494 - precision: 0.8830 - recall: 0.5697 - auc: 0.9324 - val_loss: 0.0048 - val_tp: 66.0000 - val_tn: 53284.0000 - val_fp: 13.0000 - val_fn: 39.0000 - val_precision: 0.8354 - val_recall: 0.6286 - val_auc: 0.9358
# Epoch 25/50
# 161/161 [==============================] - 1s 7ms/step - loss: 0.0040 - tp: 74.8889 - tn: 81349.3272 - fp: 8.8951 - fn: 50.8765 - precision: 0.9050 - recall: 0.5988 - auc: 0.9037 - val_loss: 0.0048 - val_tp: 68.0000 - val_tn: 53283.0000 - val_fp: 14.0000 - val_fn: 37.0000 - val_precision: 0.8293 - val_recall: 0.6476 - val_auc: 0.9358
# Epoch 26/50
# 161/161 [==============================] - 1s 7ms/step - loss: 0.0036 - tp: 77.3457 - tn: 81347.8765 - fp: 7.6728 - fn: 51.0926 - precision: 0.8995 - recall: 0.6229 - auc: 0.9254 - val_loss: 0.0046 - val_tp: 65.0000 - val_tn: 53284.0000 - val_fp: 13.0000 - val_fn: 40.0000 - val_precision: 0.8333 - val_recall: 0.6190 - val_auc: 0.9313
# Epoch 27/50
# 161/161 [==============================] - 1s 7ms/step - loss: 0.0039 - tp: 69.4630 - tn: 81354.4877 - fp: 4.7593 - fn: 55.2778 - precision: 0.9410 - recall: 0.5335 - auc: 0.9092 - val_loss: 0.0046 - val_tp: 65.0000 - val_tn: 53284.0000 - val_fp: 13.0000 - val_fn: 40.0000 - val_precision: 0.8333 - val_recall: 0.6190 - val_auc: 0.9314
# Epoch 28/50
# 161/161 [==============================] - 1s 7ms/step - loss: 0.0045 - tp: 81.2469 - tn: 81332.4198 - fp: 9.8025 - fn: 60.5185 - precision: 0.9003 - recall: 0.5682 - auc: 0.9120 - val_loss: 0.0046 - val_tp: 64.0000 - val_tn: 53284.0000 - val_fp: 13.0000 - val_fn: 41.0000 - val_precision: 0.8312 - val_recall: 0.6095 - val_auc: 0.9363
# Epoch 29/50
# 161/161 [==============================] - 1s 7ms/step - loss: 0.0034 - tp: 77.5494 - tn: 81347.1728 - fp: 8.1111 - fn: 51.1543 - precision: 0.9095 - recall: 0.6086 - auc: 0.9235 - val_loss: 0.0045 - val_tp: 65.0000 - val_tn: 53284.0000 - val_fp: 13.0000 - val_fn: 40.0000 - val_precision: 0.8333 - val_recall: 0.6190 - val_auc: 0.9361
# Epoch 30/50
# 161/161 [==============================] - 1s 7ms/step - loss: 0.0034 - tp: 69.8889 - tn: 81353.7222 - fp: 7.9444 - fn: 52.4321 - precision: 0.8857 - recall: 0.5617 - auc: 0.9102 - val_loss: 0.0046 - val_tp: 67.0000 - val_tn: 53284.0000 - val_fp: 13.0000 - val_fn: 38.0000 - val_precision: 0.8375 - val_recall: 0.6381 - val_auc: 0.9362
# Epoch 31/50
# 161/161 [==============================] - 1s 7ms/step - loss: 0.0039 - tp: 76.9938 - tn: 81342.4074 - fp: 7.8951 - fn: 56.6914 - precision: 0.8985 - recall: 0.5674 - auc: 0.9146 - val_loss: 0.0045 - val_tp: 65.0000 - val_tn: 53284.0000 - val_fp: 13.0000 - val_fn: 40.0000 - val_precision: 0.8333 - val_recall: 0.6190 - val_auc: 0.9364
# Epoch 32/50
# 161/161 [==============================] - 1s 7ms/step - loss: 0.0035 - tp: 82.1049 - tn: 81340.1049 - fp: 7.4691 - fn: 54.3086 - precision: 0.9312 - recall: 0.5963 - auc: 0.9174 - val_loss: 0.0044 - val_tp: 61.0000 - val_tn: 53286.0000 - val_fp: 11.0000 - val_fn: 44.0000 - val_precision: 0.8472 - val_recall: 0.5810 - val_auc: 0.9317
# Epoch 33/50
# 161/161 [==============================] - 1s 7ms/step - loss: 0.0035 - tp: 79.7099 - tn: 81347.7654 - fp: 5.8889 - fn: 50.6235 - precision: 0.9362 - recall: 0.6031 - auc: 0.9275 - val_loss: 0.0045 - val_tp: 69.0000 - val_tn: 53284.0000 - val_fp: 13.0000 - val_fn: 36.0000 - val_precision: 0.8415 - val_recall: 0.6571 - val_auc: 0.9363
# Epoch 34/50
# 161/161 [==============================] - 1s 7ms/step - loss: 0.0042 - tp: 84.1605 - tn: 81338.2407 - fp: 8.9259 - fn: 52.6605 - precision: 0.9111 - recall: 0.6101 - auc: 0.9061 - val_loss: 0.0044 - val_tp: 65.0000 - val_tn: 53284.0000 - val_fp: 13.0000 - val_fn: 40.0000 - val_precision: 0.8333 - val_recall: 0.6190 - val_auc: 0.9365
# Epoch 35/50
# 161/161 [==============================] - 1s 7ms/step - loss: 0.0036 - tp: 71.3210 - tn: 81348.8519 - fp: 8.8642 - fn: 54.9506 - precision: 0.9009 - recall: 0.5618 - auc: 0.9219 - val_loss: 0.0045 - val_tp: 69.0000 - val_tn: 53284.0000 - val_fp: 13.0000 - val_fn: 36.0000 - val_precision: 0.8415 - val_recall: 0.6571 - val_auc: 0.9365
# Epoch 36/50
# 161/161 [==============================] - 1s 7ms/step - loss: 0.0037 - tp: 78.0988 - tn: 81344.8951 - fp: 9.2593 - fn: 51.7346 - precision: 0.9050 - recall: 0.5830 - auc: 0.9269 - val_loss: 0.0045 - val_tp: 69.0000 - val_tn: 53284.0000 - val_fp: 13.0000 - val_fn: 36.0000 - val_precision: 0.8415 - val_recall: 0.6571 - val_auc: 0.9365
# Epoch 37/50
# 161/161 [==============================] - 1s 6ms/step - loss: 0.0032 - tp: 76.9753 - tn: 81351.5123 - fp: 8.7346 - fn: 46.7654 - precision: 0.9026 - recall: 0.6534 - auc: 0.9214 - val_loss: 0.0044 - val_tp: 69.0000 - val_tn: 53284.0000 - val_fp: 13.0000 - val_fn: 36.0000 - val_precision: 0.8415 - val_recall: 0.6571 - val_auc: 0.9365
# Epoch 38/50
# 161/161 [==============================] - 1s 7ms/step - loss: 0.0034 - tp: 75.4136 - tn: 81348.7099 - fp: 9.3519 - fn: 50.5123 - precision: 0.8808 - recall: 0.6100 - auc: 0.9264 - val_loss: 0.0044 - val_tp: 69.0000 - val_tn: 53284.0000 - val_fp: 13.0000 - val_fn: 36.0000 - val_precision: 0.8415 - val_recall: 0.6571 - val_auc: 0.9365
# Epoch 39/50
# 161/161 [==============================] - 1s 6ms/step - loss: 0.0030 - tp: 83.0741 - tn: 81351.0432 - fp: 5.9383 - fn: 43.9321 - precision: 0.9396 - recall: 0.6473 - auc: 0.9350 - val_loss: 0.0043 - val_tp: 66.0000 - val_tn: 53284.0000 - val_fp: 13.0000 - val_fn: 39.0000 - val_precision: 0.8354 - val_recall: 0.6286 - val_auc: 0.9364
# Epoch 40/50
# 161/161 [==============================] - 1s 7ms/step - loss: 0.0035 - tp: 82.6790 - tn: 81343.1420 - fp: 8.8519 - fn: 49.3148 - precision: 0.9147 - recall: 0.6348 - auc: 0.9316 - val_loss: 0.0043 - val_tp: 68.0000 - val_tn: 53284.0000 - val_fp: 13.0000 - val_fn: 37.0000 - val_precision: 0.8395 - val_recall: 0.6476 - val_auc: 0.9366
# Epoch 41/50
# 161/161 [==============================] - 1s 7ms/step - loss: 0.0038 - tp: 83.2222 - tn: 81340.7407 - fp: 7.6667 - fn: 52.3580 - precision: 0.8982 - recall: 0.5950 - auc: 0.9182 - val_loss: 0.0044 - val_tp: 68.0000 - val_tn: 53284.0000 - val_fp: 13.0000 - val_fn: 37.0000 - val_precision: 0.8395 - val_recall: 0.6476 - val_auc: 0.9367
# Epoch 42/50
# 161/161 [==============================] - 1s 7ms/step - loss: 0.0031 - tp: 80.9198 - tn: 81346.8580 - fp: 8.1790 - fn: 48.0309 - precision: 0.9135 - recall: 0.6489 - auc: 0.9264 - val_loss: 0.0043 - val_tp: 69.0000 - val_tn: 53284.0000 - val_fp: 13.0000 - val_fn: 36.0000 - val_precision: 0.8415 - val_recall: 0.6571 - val_auc: 0.9413
# Epoch 43/50
# 161/161 [==============================] - 1s 7ms/step - loss: 0.0036 - tp: 73.8951 - tn: 81346.2222 - fp: 9.5988 - fn: 54.2716 - precision: 0.8833 - recall: 0.5466 - auc: 0.9268 - val_loss: 0.0045 - val_tp: 73.0000 - val_tn: 53284.0000 - val_fp: 13.0000 - val_fn: 32.0000 - val_precision: 0.8488 - val_recall: 0.6952 - val_auc: 0.9414
# Epoch 44/50
# 161/161 [==============================] - 1s 7ms/step - loss: 0.0033 - tp: 84.4815 - tn: 81341.1111 - fp: 9.5062 - fn: 48.8889 - precision: 0.9022 - recall: 0.6320 - auc: 0.9453 - val_loss: 0.0042 - val_tp: 68.0000 - val_tn: 53285.0000 - val_fp: 12.0000 - val_fn: 37.0000 - val_precision: 0.8500 - val_recall: 0.6476 - val_auc: 0.9415
# Epoch 45/50
# 161/161 [==============================] - 1s 7ms/step - loss: 0.0032 - tp: 90.2469 - tn: 81337.9815 - fp: 8.9815 - fn: 46.7778 - precision: 0.9181 - recall: 0.6745 - auc: 0.9350 - val_loss: 0.0042 - val_tp: 69.0000 - val_tn: 53284.0000 - val_fp: 13.0000 - val_fn: 36.0000 - val_precision: 0.8415 - val_recall: 0.6571 - val_auc: 0.9414
# Epoch 46/50
# 161/161 [==============================] - 1s 6ms/step - loss: 0.0035 - tp: 81.8457 - tn: 81344.3148 - fp: 10.2346 - fn: 47.5926 - precision: 0.8726 - recall: 0.6237 - auc: 0.9337 - val_loss: 0.0043 - val_tp: 70.0000 - val_tn: 53284.0000 - val_fp: 13.0000 - val_fn: 35.0000 - val_precision: 0.8434 - val_recall: 0.6667 - val_auc: 0.9414
# Epoch 47/50
# 161/161 [==============================] - 1s 7ms/step - loss: 0.0036 - tp: 84.1296 - tn: 81343.2346 - fp: 8.4630 - fn: 48.1605 - precision: 0.9087 - recall: 0.6323 - auc: 0.9271 - val_loss: 0.0042 - val_tp: 69.0000 - val_tn: 53284.0000 - val_fp: 13.0000 - val_fn: 36.0000 - val_precision: 0.8415 - val_recall: 0.6571 - val_auc: 0.9415
# Epoch 48/50
# 161/161 [==============================] - 1s 6ms/step - loss: 0.0039 - tp: 79.8333 - tn: 81342.8580 - fp: 11.5309 - fn: 49.7654 - precision: 0.8650 - recall: 0.6235 - auc: 0.9134 - val_loss: 0.0043 - val_tp: 75.0000 - val_tn: 53284.0000 - val_fp: 13.0000 - val_fn: 30.0000 - val_precision: 0.8523 - val_recall: 0.7143 - val_auc: 0.9414
# Epoch 49/50
# 161/161 [==============================] - 1s 7ms/step - loss: 0.0038 - tp: 83.2901 - tn: 81341.7346 - fp: 9.8025 - fn: 49.1605 - precision: 0.9107 - recall: 0.6286 - auc: 0.9137 - val_loss: 0.0043 - val_tp: 74.0000 - val_tn: 53282.0000 - val_fp: 15.0000 - val_fn: 31.0000 - val_precision: 0.8315 - val_recall: 0.7048 - val_auc: 0.9415
# Epoch 50/50
# 161/161 [==============================] - 1s 7ms/step - loss: 0.0037 - tp: 79.2901 - tn: 81341.7593 - fp: 10.9691 - fn: 51.9691 - precision: 0.8687 - recall: 0.6055 - auc: 0.9242 - val_loss: 0.0043 - val_tp: 76.0000 - val_tn: 53282.0000 - val_fp: 15.0000 - val_fn: 29.0000 - val_precision: 0.8352 - val_recall: 0.7238 - val_auc: 0.9416

# %% [markdown]
# ### Model Performance

# %% [markdown]
# #### Checking Training History

# %%
# Plotting loss
loss_df = pd.DataFrame(
    {
        "Epoch": range(1, epochs + 1),
        "Train": training_history.history["loss"],
        "Val": training_history.history["val_loss"],
    }
)
loss_df.set_index("Epoch", inplace=True)
loss_df.plot(title="Loss")

# %%
# Plotting accuracy
accuracy_df = pd.DataFrame(
    {
        "Epoch": range(1, epochs + 1),
        "Val": training_history.history["val_accuracy"],
    }
)
accuracy_df.set_index("Epoch", inplace=True)
accuracy_df.plot(title="Accuracy")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-da272200e866> in <module>()
#       3     {
#       4         "Epoch": range(1, epochs + 1),
# ----> 5         "Val": training_history.history["val_accuracy"],
#       6     }
#       7 )
#
# KeyError: 'val_accuracy'

# %%
# Plotting AUC
auc_df = pd.DataFrame(
    {
        "Epoch": range(1, epochs + 1),
        "Train": training_history.history["auc"],
        "Val": training_history.history["val_auc"],
    }
)
auc_df.set_index("Epoch", inplace=True)
auc_df.plot(title="AUC")

# %% [markdown]
# #### Plotting the ROC Curve

# %%
# Import the roc_curve and auc metrics from sklearn
from sklearn.metrics import roc_curve, auc

# %%
# Making predictions to feed the roc_curve module
train_predictions = model.predict(X_train, batch_size=1000)
test_predictions = model.predict(X_test, batch_size=1000)

# %%
# Calculate the ROC curve and AUC for the training set
fpr_train, tpr_train, thresholds_train = roc_curve(y_train, train_predictions)
auc_train = auc(fpr_train, tpr_train)
auc_train = round(auc_train, 4)

# Calculate the ROC curve and AUC for the testing set
fpr_test, tpr_test, thresholds_test = roc_curve(y_test, test_predictions)
auc_test = auc(fpr_test, tpr_test)
auc_test = round(auc_test, 4)

# %%
# Create a DataFrame with the fpr and tpr results
roc_df_train = pd.DataFrame({"FPR Train": fpr_train, "TPR Train": tpr_train,})

roc_df_test = pd.DataFrame({"FPR Test": fpr_test, "TPR Test": tpr_test,})

# %%
# Plotting the ROC Curves
roc_df_train.plot(
    x="FPR Train",
    y="TPR Train",
    xlim=([-0.05, 1.05]),
    title=f"Train ROC Curve (AUC={auc_train})",
)

roc_df_test.plot(
    x="FPR Test",
    y="TPR Test",
    color="red",
    style="--",
    xlim=([-0.05, 1.05]),
    title=f"Test ROC Curve (AUC={auc_test})",
)

# %% [markdown]
# #### Evaluate the Model

# %%
# Evaluate the model
scores = model.evaluate(X_test, y_test, verbose=0)
# Define metrics dictionary
metrics = {k: v for k, v in zip(model.metrics_names, scores)}
# Display evaluation metrics results
display(metrics)
# Out:
# {'auc': 0.9526710510253906,
#  'fn': 42.0,
#  'fp': 10.0,
#  'loss': 0.003636261448264122,
#  'precision': 0.8979591727256775,
#  'recall': 0.6769230961799622,
#  'tn': 71062.0,
#  'tp': 88.0}

# %% [markdown]
# #### Confusion Matrix

# %%
# Define the confusion matrix data
cm_df = pd.DataFrame(
    {
        "Positive (1)": [f"TP={metrics['tp']}", f"FP={metrics['fn']}"],
        "Negative (0)": [f"FN={metrics['fp']}", f"TN={metrics['tn']}"],
    },
    index=["Positive(1)", "Negative(0)"],
)
cm_df.index.name = "Actual"
cm_df.columns.name = "Predicted"

# Show the confusion matrix
cm_df
# Out:
# Predicted   Positive (1) Negative (0)
# Actual
# Positive(1)      TP=88.0      FN=10.0
# Negative(0)      FP=42.0   TN=71062.0

# %% [markdown]
# #### Classification Report

# %%
# Import the classification_report method from sklearn
from sklearn.metrics import classification_report

# Predict classes using testing data
y_predict_classes = model.predict_classes(X_test, batch_size=1000)

# Display classification report
print(classification_report(y_predict_classes, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     71104
#            1       0.68      0.90      0.77        98
#
#     accuracy                           1.00     71202
#    macro avg       0.84      0.95      0.89     71202
# weighted avg       1.00      1.00      1.00     71202
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
